# %%
# !pip install midiutil
# !pip install pydub numpy
# !apt-get install ffmpeg
# Out:
# Collecting midiutil
#   Downloading MIDIUtil-1.2.1.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: midiutil
#   Building wheel for midiutil (setup.py) ... done
#   Created wheel for midiutil: filename=MIDIUtil-1.2.1-py3-none-any.whl size=54569 sha256=46d7bffa1e9ec33d2b21fe0c4eff48e39572e0fa6556a01f908ccd1b5a9e4682
#   Stored in directory: /root/.cache/pip/wheels/6c/42/75/fce10c67f06fe627fad8acd1fd3a004a24e07b0f077761fbbd
# Successfully built midiutil
# Installing collected packages: midiutil
# Successfully installed midiutil-1.2.1
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
from midiutil import MIDIFile
import os
import subprocess
import numpy as np
from scipy.io import wavfile
from pathlib import Path
from google.colab import drive
import time as time_module  # Renamed to avoid conflict

# Mount Google Drive
drive.mount('/content/drive')

# Define the paths
base_dir = '/content/drive/MyDrive/MusicGenerator'
midi_dir = os.path.join(base_dir, "midi")
wav_dir = os.path.join(base_dir, "wav")

# Create directories if they don't exist
chord_type = "major"
midi_chord_dir = os.path.join(midi_dir, "chords", chord_type)
wav_chord_dir = os.path.join(wav_dir, "chords", chord_type)

# Create necessary directories
Path(midi_chord_dir).mkdir(parents=True, exist_ok=True)
Path(wav_chord_dir).mkdir(parents=True, exist_ok=True)

print(f"Created MIDI directory: {midi_chord_dir}")
print(f"Created WAV directory: {wav_chord_dir}")

# Install required packages if needed
try:
    import scipy
except ImportError:
    print("Installing scipy...")
    subprocess.run(['pip', 'install', 'scipy'], check=True)
    from scipy.io import wavfile

noteArray = ["C", "C#", "D", "Eb", "E", "F", "F#", "G", "Ab", "A", "Bb", "B"]
octaveArray = [1, 2, 3, 4, 5, 6, 7, 8]

# Generate note names with octaves (C-1, C-2, etc.)
nameArray = []
for octave in octaveArray:
    for note in noteArray:
        nameArray.append(f"{note}-{octave}")

# Major triad parameters
offset1 = 4  # 4 semitones from root to third in a major triad
offset2 = 3  # 3 semitones from third to fifth in a major triad

# Function to add background noise to audio while preserving original volume
def add_noise(audio_data, noise_level):
    """
    Add background noise to audio at specified level without reducing original volume
    noise_level: 0 to 5, where 0 is no noise and 5 is maximum noise
    Returns: audio with added noise, maintaining original signal strength
    """
    # Scale noise level (0-5) to amplitude - SIGNIFICANTLY REDUCED
    # Reducing base amplitude by more than half and using a gentler exponential scale
    base_amplitude = 0.06  # Reduced from 0.15 (60% reduction)
    # Using a much gentler exponential factor (1.8 instead of 3)
    noise_amplitude = base_amplitude * (1.8 ** noise_level) / 32  # Much gentler scaling

    # This combination reduces noise by well over 50% at all levels

    # Convert to float64 for better precision during processing
    audio_float = audio_data.astype(np.float64)

    # Get the maximum value for the audio data type
    max_value = np.iinfo(audio_data.dtype).max

    # Check if audio is stereo (2D array) or mono (1D array)
    is_stereo = len(audio_data.shape) > 1 and audio_data.shape[1] > 1

    # Generate white noise instead of Gaussian noise
    if is_stereo:
        # White noise for stereo (same distribution for both channels)
        noise = np.random.uniform(-max_value * noise_amplitude, max_value * noise_amplitude, audio_data.shape).astype(np.float64)
    else:
        # White noise for mono
        noise = np.random.uniform(-max_value * noise_amplitude, max_value * noise_amplitude, audio_data.shape[0]).astype(np.float64)

    # Calculate mixing ratio based on noise level
    # This ensures the original signal maintains its volume
    signal_weight = 1.0  # Keep original signal at 100%

    # Mix signal and noise with proper weighting
    mixed_audio = (signal_weight * audio_float) + noise

    # Clip to valid range for the data type
    mixed_audio_clipped = np.clip(mixed_audio, np.iinfo(audio_data.dtype).min, np.iinfo(audio_data.dtype).max)

    # Convert back to original data type
    return mixed_audio_clipped.astype(audio_data.dtype)

def createTriad(inversion, base, offset1, offset2):
    if(inversion==0):
        note1 = base
        note2 = base+offset1
        note3 = note2+offset2

    elif(inversion==1):
        note1 = base+offset1
        note2 = note1+offset2
        note3 = base+12

    elif(inversion==2):
        note1 = base+offset1+offset2
        note2 = base+12
        note3 = note2+offset1

    return note1, note2, note3

print("Generating major triad chord MIDI files...")

# Counter for generated files
file_count = 0

# Limit to a subset of octaves to keep the number of generated files manageable
limited_octaves = [1, 2, 3, 4, 5, 6, 7, 8]  # Using octaves 3-5

# Create a list to collect note information
note_list = []

for q, j in zip(nameArray, range(24,109)):
    # Get octave from the note name
    note_parts = q.split('-')
    if len(note_parts) == 2 and note_parts[1].isdigit():
        octave = int(note_parts[1])
        # Only process notes in our limited octave range
        if octave in limited_octaves:
            note_list.append((q, j))

# Process the collected notes
for noteName, base in note_list:
    for h in range(0, 3):  # Loop through all 3 inversions
        inversion = h

        appendInversion = "-"+str(inversion)

        note1, note2, note3 = createTriad(inversion, base, offset1, offset2)
        degrees = [note1, note2, note3]

        track    = 0
        channel  = 0
        time_pos = 0    # In beats (renamed from 'time' to avoid conflict)
        duration = 1    # In beats
        tempo    = 60   # In BPM
        volume   = 100  # 0-127, as per the MIDI standard

        MyMIDI = MIDIFile(1)  # One track
        MyMIDI.addTempo(track, time_pos, tempo)

        # Generate chord (all notes played simultaneously)
        for pitch in degrees:
            MyMIDI.addNote(track, channel, pitch, time_pos, duration, volume)

        midiName = noteName+'-'+chord_type+'-chord'+appendInversion+".mid"
        midi_filename = os.path.join(midi_chord_dir, midiName)

        with open(midi_filename, "wb") as output_file:
            MyMIDI.writeFile(output_file)
            file_count += 1

            # Print progress every 10 files
            if file_count % 10 == 0:
                print(f"Generated {file_count} MIDI files...")

print(f"Completed! Generated {file_count} major triad chord MIDI files.")

# Install timidity if not already installed
try:
    subprocess.run(['which', 'timidity'], check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("TiMidity++ is already installed.")
except subprocess.CalledProcessError:
    print("Installing TiMidity++...")
    subprocess.run(['apt-get', 'update'], check=True)
    subprocess.run(['apt-get', 'install', '-y', 'timidity'], check=True)
    print("TiMidity++ installed successfully.")

# Convert MIDI files to WAV with different noise levels
print("\nConverting MIDI files to WAV format with varying noise levels (0-5)...")
wav_count = 0

# Get all MIDI files in the chord directory
midi_files = [f for f in os.listdir(midi_chord_dir) if f.endswith('.mid')]
total_midi_files = len(midi_files)
total_conversions = total_midi_files * 6  # 6 versions of each file (noise levels 0-5)

for idx, midi_file in enumerate(midi_files):
    midi_path = os.path.join(midi_chord_dir, midi_file)
    base_name = Path(midi_file).stem

    print(f"Processing {idx+1}/{total_midi_files}: {midi_file}")

    # First, convert to WAV without noise (temp file)
    temp_wav_path = os.path.join('/tmp', f"{base_name}_temp.wav")

    try:
        # Run timidity with a timeout to prevent hanging
        # Increase the volume of the MIDI files when converting to make them more prominent
        timidity_process = subprocess.run(
            ['timidity', midi_path, '-Ow1', '-s', '16kHz', '-A', '200', '-o', temp_wav_path],
            stdout=subprocess.PIPE, stderr=subprocess.PIPE,
            timeout=10  # Set a 10-second timeout for conversion
        )

        # Check if the temp file was created
        if not os.path.exists(temp_wav_path):
            print(f"Warning: Failed to create WAV file for {midi_file}")
            continue

        # Read the WAV file
        sample_rate, audio_data = wavfile.read(temp_wav_path)

        # Create versions with different noise levels
        for noise_level in range(6):  # 0 to 5
            # Add appropriate level of noise
            if noise_level == 0:
                # No noise for level 0
                noisy_audio = audio_data
            else:
                # Add increasing levels of noise
                noisy_audio = add_noise(audio_data, noise_level)

            # Save to final WAV file with noise level in filename
            wav_file = os.path.join(wav_chord_dir, f"{base_name}_noise{noise_level}.wav")
            wavfile.write(wav_file, sample_rate, noisy_audio)
            wav_count += 1

        # Success message for this file
        print(f"Created 6 variations with different noise levels for {midi_file}")

    except subprocess.TimeoutExpired:
        print(f"Warning: Conversion timeout for {midi_file}")
    except Exception as e:
        print(f"Error processing {midi_file}: {str(e)}")

    # Clean up temp file
    if os.path.exists(temp_wav_path):
        os.remove(temp_wav_path)

    # Add a small delay to prevent overwhelming the system
    time_module.sleep(0.1)  # Using the renamed time module

print(f"\nAll done! Generated {file_count} major triad chord MIDI files and {wav_count} WAV files with varying noise levels.")
print(f"MIDI files are in: {midi_chord_dir}")
print(f"WAV files are in: {wav_chord_dir}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Created MIDI directory: /content/drive/MyDrive/MusicGenerator/midi/chords/major
# Created WAV directory: /content/drive/MyDrive/MusicGenerator/wav/chords/major
# Generating major triad chord MIDI files...
# Generated 10 MIDI files...
# Generated 20 MIDI files...
# Generated 30 MIDI files...
# Generated 40 MIDI files...
# Generated 50 MIDI files...
# Generated 60 MIDI files...
# Generated 70 MIDI files...
# Generated 80 MIDI files...
# Generated 90 MIDI files...
# Generated 100 MIDI files...
# Generated 110 MIDI files...
# Generated 120 MIDI files...
# Generated 130 MIDI files...
# Generated 140 MIDI files...
# Generated 150 MIDI files...
# Generated 160 MIDI files...
# Generated 170 MIDI files...
# Generated 180 MIDI files...
# Generated 190 MIDI files...
# Generated 200 MIDI files...
# Generated 210 MIDI files...
# Generated 220 MIDI files...
# Generated 230 MIDI files...
# Generated 240 MIDI files...
# Generated 250 MIDI files...
# Completed! Generated 255 major triad chord MIDI files.
# TiMidity++ is already installed.
#
# Converting MIDI files to WAV format with varying noise levels (0-5)...
# Processing 1/255: C-3-major-chord-0.mid
# Created 6 variations with different noise levels for C-3-major-chord-0.mid
# Processing 2/255: C-3-major-chord-1.mid
# Created 6 variations with different noise levels for C-3-major-chord-1.mid
# Processing 3/255: C-3-major-chord-2.mid
# Created 6 variations with different noise levels for C-3-major-chord-2.mid
# Processing 4/255: C#-3-major-chord-0.mid
# Created 6 variations with different noise levels for C#-3-major-chord-0.mid
# Processing 5/255: C#-3-major-chord-1.mid
# Created 6 variations with different noise levels for C#-3-major-chord-1.mid
# Processing 6/255: C#-3-major-chord-2.mid
# Created 6 variations with different noise levels for C#-3-major-chord-2.mid
# Processing 7/255: D-3-major-chord-0.mid
# Created 6 variations with different noise levels for D-3-major-chord-0.mid
# Processing 8/255: D-3-major-chord-1.mid
# Created 6 variations with different noise levels for D-3-major-chord-1.mid
# Processing 9/255: D-3-major-chord-2.mid
# Created 6 variations with different noise levels for D-3-major-chord-2.mid
# Processing 10/255: Eb-3-major-chord-0.mid
# Created 6 variations with different noise levels for Eb-3-major-chord-0.mid
# Processing 11/255: Eb-3-major-chord-1.mid
# Created 6 variations with different noise levels for Eb-3-major-chord-1.mid
# Processing 12/255: Eb-3-major-chord-2.mid
# Created 6 variations with different noise levels for Eb-3-major-chord-2.mid
# Processing 13/255: E-3-major-chord-0.mid
# Created 6 variations with different noise levels for E-3-major-chord-0.mid
# Processing 14/255: E-3-major-chord-1.mid
# Created 6 variations with different noise levels for E-3-major-chord-1.mid
# Processing 15/255: E-3-major-chord-2.mid
# Created 6 variations with different noise levels for E-3-major-chord-2.mid
# Processing 16/255: F-3-major-chord-0.mid
# Created 6 variations with different noise levels for F-3-major-chord-0.mid
# Processing 17/255: F-3-major-chord-1.mid
# Created 6 variations with different noise levels for F-3-major-chord-1.mid
# Processing 18/255: F-3-major-chord-2.mid
# Created 6 variations with different noise levels for F-3-major-chord-2.mid
# Processing 19/255: F#-3-major-chord-0.mid
# Created 6 variations with different noise levels for F#-3-major-chord-0.mid
# Processing 20/255: F#-3-major-chord-1.mid
# Created 6 variations with different noise levels for F#-3-major-chord-1.mid
# Processing 21/255: F#-3-major-chord-2.mid
# Created 6 variations with different noise levels for F#-3-major-chord-2.mid
# Processing 22/255: G-3-major-chord-0.mid
# Created 6 variations with different noise levels for G-3-major-chord-0.mid
# Processing 23/255: G-3-major-chord-1.mid
# Created 6 variations with different noise levels for G-3-major-chord-1.mid
# Processing 24/255: G-3-major-chord-2.mid
# Created 6 variations with different noise levels for G-3-major-chord-2.mid
# Processing 25/255: Ab-3-major-chord-0.mid
# Created 6 variations with different noise levels for Ab-3-major-chord-0.mid
# Processing 26/255: Ab-3-major-chord-1.mid
# Created 6 variations with different noise levels for Ab-3-major-chord-1.mid
# Processing 27/255: Ab-3-major-chord-2.mid
# Created 6 variations with different noise levels for Ab-3-major-chord-2.mid
# Processing 28/255: A-3-major-chord-0.mid
# Created 6 variations with different noise levels for A-3-major-chord-0.mid
# Processing 29/255: A-3-major-chord-1.mid
# Created 6 variations with different noise levels for A-3-major-chord-1.mid
# Processing 30/255: A-3-major-chord-2.mid
# Created 6 variations with different noise levels for A-3-major-chord-2.mid
# Processing 31/255: Bb-3-major-chord-0.mid
# Created 6 variations with different noise levels for Bb-3-major-chord-0.mid
# Processing 32/255: Bb-3-major-chord-1.mid
# Created 6 variations with different noise levels for Bb-3-major-chord-1.mid
# Processing 33/255: Bb-3-major-chord-2.mid
# Created 6 variations with different noise levels for Bb-3-major-chord-2.mid
# Processing 34/255: B-3-major-chord-0.mid
# Created 6 variations with different noise levels for B-3-major-chord-0.mid
# Processing 35/255: B-3-major-chord-1.mid
# Created 6 variations with different noise levels for B-3-major-chord-1.mid
# Processing 36/255: B-3-major-chord-2.mid
# Created 6 variations with different noise levels for B-3-major-chord-2.mid
# Processing 37/255: C-4-major-chord-0.mid
# Created 6 variations with different noise levels for C-4-major-chord-0.mid
# Processing 38/255: C-4-major-chord-1.mid
# Created 6 variations with different noise levels for C-4-major-chord-1.mid
# Processing 39/255: C-4-major-chord-2.mid
# Created 6 variations with different noise levels for C-4-major-chord-2.mid
# Processing 40/255: C#-4-major-chord-0.mid
# Created 6 variations with different noise levels for C#-4-major-chord-0.mid
# Processing 41/255: C#-4-major-chord-1.mid
# Created 6 variations with different noise levels for C#-4-major-chord-1.mid
# Processing 42/255: C#-4-major-chord-2.mid
# Created 6 variations with different noise levels for C#-4-major-chord-2.mid
# Processing 43/255: D-4-major-chord-0.mid
# Created 6 variations with different noise levels for D-4-major-chord-0.mid
# Processing 44/255: D-4-major-chord-1.mid
# Created 6 variations with different noise levels for D-4-major-chord-1.mid
# Processing 45/255: D-4-major-chord-2.mid
# Created 6 variations with different noise levels for D-4-major-chord-2.mid
# Processing 46/255: Eb-4-major-chord-0.mid
# Created 6 variations with different noise levels for Eb-4-major-chord-0.mid
# Processing 47/255: Eb-4-major-chord-1.mid
# Created 6 variations with different noise levels for Eb-4-major-chord-1.mid
# Processing 48/255: Eb-4-major-chord-2.mid
# Created 6 variations with different noise levels for Eb-4-major-chord-2.mid
# Processing 49/255: E-4-major-chord-0.mid
# Created 6 variations with different noise levels for E-4-major-chord-0.mid
# Processing 50/255: E-4-major-chord-1.mid
# Created 6 variations with different noise levels for E-4-major-chord-1.mid
# Processing 51/255: E-4-major-chord-2.mid
# Created 6 variations with different noise levels for E-4-major-chord-2.mid
# Processing 52/255: F-4-major-chord-0.mid
# Created 6 variations with different noise levels for F-4-major-chord-0.mid
# Processing 53/255: F-4-major-chord-1.mid
# Created 6 variations with different noise levels for F-4-major-chord-1.mid
# Processing 54/255: F-4-major-chord-2.mid
# Created 6 variations with different noise levels for F-4-major-chord-2.mid
# Processing 55/255: F#-4-major-chord-0.mid
# Created 6 variations with different noise levels for F#-4-major-chord-0.mid
# Processing 56/255: F#-4-major-chord-1.mid
# Created 6 variations with different noise levels for F#-4-major-chord-1.mid
# Processing 57/255: F#-4-major-chord-2.mid
# Created 6 variations with different noise levels for F#-4-major-chord-2.mid
# Processing 58/255: G-4-major-chord-0.mid
# Created 6 variations with different noise levels for G-4-major-chord-0.mid
# Processing 59/255: G-4-major-chord-1.mid
# Created 6 variations with different noise levels for G-4-major-chord-1.mid
# Processing 60/255: G-4-major-chord-2.mid
# Created 6 variations with different noise levels for G-4-major-chord-2.mid
# Processing 61/255: Ab-4-major-chord-0.mid
# Created 6 variations with different noise levels for Ab-4-major-chord-0.mid
# Processing 62/255: Ab-4-major-chord-1.mid
# Created 6 variations with different noise levels for Ab-4-major-chord-1.mid
# Processing 63/255: Ab-4-major-chord-2.mid
# Created 6 variations with different noise levels for Ab-4-major-chord-2.mid
# Processing 64/255: A-4-major-chord-0.mid
# Created 6 variations with different noise levels for A-4-major-chord-0.mid
# Processing 65/255: A-4-major-chord-1.mid
# Created 6 variations with different noise levels for A-4-major-chord-1.mid
# Processing 66/255: A-4-major-chord-2.mid
# Created 6 variations with different noise levels for A-4-major-chord-2.mid
# Processing 67/255: Bb-4-major-chord-0.mid
# Created 6 variations with different noise levels for Bb-4-major-chord-0.mid
# Processing 68/255: Bb-4-major-chord-1.mid
# Created 6 variations with different noise levels for Bb-4-major-chord-1.mid
# Processing 69/255: Bb-4-major-chord-2.mid
# Created 6 variations with different noise levels for Bb-4-major-chord-2.mid
# Processing 70/255: B-4-major-chord-0.mid
# Created 6 variations with different noise levels for B-4-major-chord-0.mid
# Processing 71/255: B-4-major-chord-1.mid
# Created 6 variations with different noise levels for B-4-major-chord-1.mid
# Processing 72/255: B-4-major-chord-2.mid
# Created 6 variations with different noise levels for B-4-major-chord-2.mid
# Processing 73/255: C-5-major-chord-0.mid
# Created 6 variations with different noise levels for C-5-major-chord-0.mid
# Processing 74/255: C-5-major-chord-1.mid
# Created 6 variations with different noise levels for C-5-major-chord-1.mid
# Processing 75/255: C-5-major-chord-2.mid
# Created 6 variations with different noise levels for C-5-major-chord-2.mid
# Processing 76/255: C#-5-major-chord-0.mid
# Created 6 variations with different noise levels for C#-5-major-chord-0.mid
# Processing 77/255: C#-5-major-chord-1.mid
# Created 6 variations with different noise levels for C#-5-major-chord-1.mid
# Processing 78/255: C#-5-major-chord-2.mid
# Created 6 variations with different noise levels for C#-5-major-chord-2.mid
# Processing 79/255: D-5-major-chord-0.mid
# Created 6 variations with different noise levels for D-5-major-chord-0.mid
# Processing 80/255: D-5-major-chord-1.mid
# Created 6 variations with different noise levels for D-5-major-chord-1.mid
# Processing 81/255: D-5-major-chord-2.mid
# Created 6 variations with different noise levels for D-5-major-chord-2.mid
# Processing 82/255: Eb-5-major-chord-0.mid
# Created 6 variations with different noise levels for Eb-5-major-chord-0.mid
# Processing 83/255: Eb-5-major-chord-1.mid
# Created 6 variations with different noise levels for Eb-5-major-chord-1.mid
# Processing 84/255: Eb-5-major-chord-2.mid
# Created 6 variations with different noise levels for Eb-5-major-chord-2.mid
# Processing 85/255: E-5-major-chord-0.mid
# Created 6 variations with different noise levels for E-5-major-chord-0.mid
# Processing 86/255: E-5-major-chord-1.mid
# Created 6 variations with different noise levels for E-5-major-chord-1.mid
# Processing 87/255: E-5-major-chord-2.mid
# Created 6 variations with different noise levels for E-5-major-chord-2.mid
# Processing 88/255: F-5-major-chord-0.mid
# Created 6 variations with different noise levels for F-5-major-chord-0.mid
# Processing 89/255: F-5-major-chord-1.mid
# Created 6 variations with different noise levels for F-5-major-chord-1.mid
# Processing 90/255: F-5-major-chord-2.mid
# Created 6 variations with different noise levels for F-5-major-chord-2.mid
# Processing 91/255: F#-5-major-chord-0.mid
# Created 6 variations with different noise levels for F#-5-major-chord-0.mid
# Processing 92/255: F#-5-major-chord-1.mid
# Created 6 variations with different noise levels for F#-5-major-chord-1.mid
# Processing 93/255: F#-5-major-chord-2.mid
# Created 6 variations with different noise levels for F#-5-major-chord-2.mid
# Processing 94/255: G-5-major-chord-0.mid
# Created 6 variations with different noise levels for G-5-major-chord-0.mid
# Processing 95/255: G-5-major-chord-1.mid
# Created 6 variations with different noise levels for G-5-major-chord-1.mid
# Processing 96/255: G-5-major-chord-2.mid
# Created 6 variations with different noise levels for G-5-major-chord-2.mid
# Processing 97/255: Ab-5-major-chord-0.mid
# Created 6 variations with different noise levels for Ab-5-major-chord-0.mid
# Processing 98/255: Ab-5-major-chord-1.mid
# Created 6 variations with different noise levels for Ab-5-major-chord-1.mid
# Processing 99/255: Ab-5-major-chord-2.mid
# Created 6 variations with different noise levels for Ab-5-major-chord-2.mid
# Processing 100/255: A-5-major-chord-0.mid
# Created 6 variations with different noise levels for A-5-major-chord-0.mid
# Processing 101/255: A-5-major-chord-1.mid
# Created 6 variations with different noise levels for A-5-major-chord-1.mid
# Processing 102/255: A-5-major-chord-2.mid
# Created 6 variations with different noise levels for A-5-major-chord-2.mid
# Processing 103/255: Bb-5-major-chord-0.mid
# Created 6 variations with different noise levels for Bb-5-major-chord-0.mid
# Processing 104/255: Bb-5-major-chord-1.mid
# Created 6 variations with different noise levels for Bb-5-major-chord-1.mid
# Processing 105/255: Bb-5-major-chord-2.mid
# Created 6 variations with different noise levels for Bb-5-major-chord-2.mid
# Processing 106/255: B-5-major-chord-0.mid
# Created 6 variations with different noise levels for B-5-major-chord-0.mid
# Processing 107/255: B-5-major-chord-1.mid
# Created 6 variations with different noise levels for B-5-major-chord-1.mid
# Processing 108/255: B-5-major-chord-2.mid
# Created 6 variations with different noise levels for B-5-major-chord-2.mid
# Processing 109/255: C-1-major-chord-0.mid
# Created 6 variations with different noise levels for C-1-major-chord-0.mid
# Processing 110/255: C-1-major-chord-1.mid
# Created 6 variations with different noise levels for C-1-major-chord-1.mid
# Processing 111/255: C-1-major-chord-2.mid
# Created 6 variations with different noise levels for C-1-major-chord-2.mid
# Processing 112/255: C#-1-major-chord-0.mid
# Created 6 variations with different noise levels for C#-1-major-chord-0.mid
# Processing 113/255: C#-1-major-chord-1.mid
# Created 6 variations with different noise levels for C#-1-major-chord-1.mid
# Processing 114/255: C#-1-major-chord-2.mid
# Created 6 variations with different noise levels for C#-1-major-chord-2.mid
# Processing 115/255: D-1-major-chord-0.mid
# Created 6 variations with different noise levels for D-1-major-chord-0.mid
# Processing 116/255: D-1-major-chord-1.mid
# Created 6 variations with different noise levels for D-1-major-chord-1.mid
# Processing 117/255: D-1-major-chord-2.mid
# Created 6 variations with different noise levels for D-1-major-chord-2.mid
# Processing 118/255: Eb-1-major-chord-0.mid
# Created 6 variations with different noise levels for Eb-1-major-chord-0.mid
# Processing 119/255: Eb-1-major-chord-1.mid
# Created 6 variations with different noise levels for Eb-1-major-chord-1.mid
# Processing 120/255: Eb-1-major-chord-2.mid
# Created 6 variations with different noise levels for Eb-1-major-chord-2.mid
# Processing 121/255: E-1-major-chord-0.mid
# Created 6 variations with different noise levels for E-1-major-chord-0.mid
# Processing 122/255: E-1-major-chord-1.mid
# Created 6 variations with different noise levels for E-1-major-chord-1.mid
# Processing 123/255: E-1-major-chord-2.mid
# Created 6 variations with different noise levels for E-1-major-chord-2.mid
# Processing 124/255: F-1-major-chord-0.mid
# Created 6 variations with different noise levels for F-1-major-chord-0.mid
# Processing 125/255: F-1-major-chord-1.mid
# Created 6 variations with different noise levels for F-1-major-chord-1.mid
# Processing 126/255: F-1-major-chord-2.mid
# Created 6 variations with different noise levels for F-1-major-chord-2.mid
# Processing 127/255: F#-1-major-chord-0.mid
# Created 6 variations with different noise levels for F#-1-major-chord-0.mid
# Processing 128/255: F#-1-major-chord-1.mid
# Created 6 variations with different noise levels for F#-1-major-chord-1.mid
# Processing 129/255: F#-1-major-chord-2.mid
# Created 6 variations with different noise levels for F#-1-major-chord-2.mid
# Processing 130/255: G-1-major-chord-0.mid
# Created 6 variations with different noise levels for G-1-major-chord-0.mid
# Processing 131/255: G-1-major-chord-1.mid
# Created 6 variations with different noise levels for G-1-major-chord-1.mid
# Processing 132/255: G-1-major-chord-2.mid
# Created 6 variations with different noise levels for G-1-major-chord-2.mid
# Processing 133/255: Ab-1-major-chord-0.mid
# Created 6 variations with different noise levels for Ab-1-major-chord-0.mid
# Processing 134/255: Ab-1-major-chord-1.mid
# Created 6 variations with different noise levels for Ab-1-major-chord-1.mid
# Processing 135/255: Ab-1-major-chord-2.mid
# Created 6 variations with different noise levels for Ab-1-major-chord-2.mid
# Processing 136/255: A-1-major-chord-0.mid
# Created 6 variations with different noise levels for A-1-major-chord-0.mid
# Processing 137/255: A-1-major-chord-1.mid
# Created 6 variations with different noise levels for A-1-major-chord-1.mid
# Processing 138/255: A-1-major-chord-2.mid
# Created 6 variations with different noise levels for A-1-major-chord-2.mid
# Processing 139/255: Bb-1-major-chord-0.mid
# Created 6 variations with different noise levels for Bb-1-major-chord-0.mid
# Processing 140/255: Bb-1-major-chord-1.mid
# Created 6 variations with different noise levels for Bb-1-major-chord-1.mid
# Processing 141/255: Bb-1-major-chord-2.mid
# Created 6 variations with different noise levels for Bb-1-major-chord-2.mid
# Processing 142/255: B-1-major-chord-0.mid
# Created 6 variations with different noise levels for B-1-major-chord-0.mid
# Processing 143/255: B-1-major-chord-1.mid
# Created 6 variations with different noise levels for B-1-major-chord-1.mid
# Processing 144/255: B-1-major-chord-2.mid
# Created 6 variations with different noise levels for B-1-major-chord-2.mid
# Processing 145/255: C-2-major-chord-0.mid
# Created 6 variations with different noise levels for C-2-major-chord-0.mid
# Processing 146/255: C-2-major-chord-1.mid
# Created 6 variations with different noise levels for C-2-major-chord-1.mid
# Processing 147/255: C-2-major-chord-2.mid
# Created 6 variations with different noise levels for C-2-major-chord-2.mid
# Processing 148/255: C#-2-major-chord-0.mid
# Created 6 variations with different noise levels for C#-2-major-chord-0.mid
# Processing 149/255: C#-2-major-chord-1.mid
# Created 6 variations with different noise levels for C#-2-major-chord-1.mid
# Processing 150/255: C#-2-major-chord-2.mid
# Created 6 variations with different noise levels for C#-2-major-chord-2.mid
# Processing 151/255: D-2-major-chord-0.mid
# Created 6 variations with different noise levels for D-2-major-chord-0.mid
# Processing 152/255: D-2-major-chord-1.mid
# Created 6 variations with different noise levels for D-2-major-chord-1.mid
# Processing 153/255: D-2-major-chord-2.mid
# Created 6 variations with different noise levels for D-2-major-chord-2.mid
# Processing 154/255: Eb-2-major-chord-0.mid
# Created 6 variations with different noise levels for Eb-2-major-chord-0.mid
# Processing 155/255: Eb-2-major-chord-1.mid
# Created 6 variations with different noise levels for Eb-2-major-chord-1.mid
# Processing 156/255: Eb-2-major-chord-2.mid
# Created 6 variations with different noise levels for Eb-2-major-chord-2.mid
# Processing 157/255: E-2-major-chord-0.mid
# Created 6 variations with different noise levels for E-2-major-chord-0.mid
# Processing 158/255: E-2-major-chord-1.mid
# Created 6 variations with different noise levels for E-2-major-chord-1.mid
# Processing 159/255: E-2-major-chord-2.mid
# Created 6 variations with different noise levels for E-2-major-chord-2.mid
# Processing 160/255: F-2-major-chord-0.mid
# Created 6 variations with different noise levels for F-2-major-chord-0.mid
# Processing 161/255: F-2-major-chord-1.mid
# Created 6 variations with different noise levels for F-2-major-chord-1.mid
# Processing 162/255: F-2-major-chord-2.mid
# Created 6 variations with different noise levels for F-2-major-chord-2.mid
# Processing 163/255: F#-2-major-chord-0.mid
# Created 6 variations with different noise levels for F#-2-major-chord-0.mid
# Processing 164/255: F#-2-major-chord-1.mid
# Created 6 variations with different noise levels for F#-2-major-chord-1.mid
# Processing 165/255: F#-2-major-chord-2.mid
# Created 6 variations with different noise levels for F#-2-major-chord-2.mid
# Processing 166/255: G-2-major-chord-0.mid
# Created 6 variations with different noise levels for G-2-major-chord-0.mid
# Processing 167/255: G-2-major-chord-1.mid
# Created 6 variations with different noise levels for G-2-major-chord-1.mid
# Processing 168/255: G-2-major-chord-2.mid
# Created 6 variations with different noise levels for G-2-major-chord-2.mid
# Processing 169/255: Ab-2-major-chord-0.mid
# Created 6 variations with different noise levels for Ab-2-major-chord-0.mid
# Processing 170/255: Ab-2-major-chord-1.mid
# Created 6 variations with different noise levels for Ab-2-major-chord-1.mid
# Processing 171/255: Ab-2-major-chord-2.mid
# Created 6 variations with different noise levels for Ab-2-major-chord-2.mid
# Processing 172/255: A-2-major-chord-0.mid
# Created 6 variations with different noise levels for A-2-major-chord-0.mid
# Processing 173/255: A-2-major-chord-1.mid
# Created 6 variations with different noise levels for A-2-major-chord-1.mid
# Processing 174/255: A-2-major-chord-2.mid
# Created 6 variations with different noise levels for A-2-major-chord-2.mid
# Processing 175/255: Bb-2-major-chord-0.mid
# Created 6 variations with different noise levels for Bb-2-major-chord-0.mid
# Processing 176/255: Bb-2-major-chord-1.mid
# Created 6 variations with different noise levels for Bb-2-major-chord-1.mid
# Processing 177/255: Bb-2-major-chord-2.mid
# Created 6 variations with different noise levels for Bb-2-major-chord-2.mid
# Processing 178/255: B-2-major-chord-0.mid
# Created 6 variations with different noise levels for B-2-major-chord-0.mid
# Processing 179/255: B-2-major-chord-1.mid
# Created 6 variations with different noise levels for B-2-major-chord-1.mid
# Processing 180/255: B-2-major-chord-2.mid
# Created 6 variations with different noise levels for B-2-major-chord-2.mid
# Processing 181/255: C-6-major-chord-0.mid
# Created 6 variations with different noise levels for C-6-major-chord-0.mid
# Processing 182/255: C-6-major-chord-1.mid
# Created 6 variations with different noise levels for C-6-major-chord-1.mid
# Processing 183/255: C-6-major-chord-2.mid
# Created 6 variations with different noise levels for C-6-major-chord-2.mid
# Processing 184/255: C#-6-major-chord-0.mid
# Created 6 variations with different noise levels for C#-6-major-chord-0.mid
# Processing 185/255: C#-6-major-chord-1.mid
# Created 6 variations with different noise levels for C#-6-major-chord-1.mid
# Processing 186/255: C#-6-major-chord-2.mid
# Created 6 variations with different noise levels for C#-6-major-chord-2.mid
# Processing 187/255: D-6-major-chord-0.mid
# Created 6 variations with different noise levels for D-6-major-chord-0.mid
# Processing 188/255: D-6-major-chord-1.mid
# Created 6 variations with different noise levels for D-6-major-chord-1.mid
# Processing 189/255: D-6-major-chord-2.mid
# Created 6 variations with different noise levels for D-6-major-chord-2.mid
# Processing 190/255: Eb-6-major-chord-0.mid
# Created 6 variations with different noise levels for Eb-6-major-chord-0.mid
# Processing 191/255: Eb-6-major-chord-1.mid
# Created 6 variations with different noise levels for Eb-6-major-chord-1.mid
# Processing 192/255: Eb-6-major-chord-2.mid
# Created 6 variations with different noise levels for Eb-6-major-chord-2.mid
# Processing 193/255: E-6-major-chord-0.mid
# Created 6 variations with different noise levels for E-6-major-chord-0.mid
# Processing 194/255: E-6-major-chord-1.mid
# Created 6 variations with different noise levels for E-6-major-chord-1.mid
# Processing 195/255: E-6-major-chord-2.mid
# Created 6 variations with different noise levels for E-6-major-chord-2.mid
# Processing 196/255: F-6-major-chord-0.mid
# Created 6 variations with different noise levels for F-6-major-chord-0.mid
# Processing 197/255: F-6-major-chord-1.mid
# Created 6 variations with different noise levels for F-6-major-chord-1.mid
# Processing 198/255: F-6-major-chord-2.mid
# Created 6 variations with different noise levels for F-6-major-chord-2.mid
# Processing 199/255: F#-6-major-chord-0.mid
# Created 6 variations with different noise levels for F#-6-major-chord-0.mid
# Processing 200/255: F#-6-major-chord-1.mid
# Created 6 variations with different noise levels for F#-6-major-chord-1.mid
# Processing 201/255: F#-6-major-chord-2.mid
# Created 6 variations with different noise levels for F#-6-major-chord-2.mid
# Processing 202/255: G-6-major-chord-0.mid
# Created 6 variations with different noise levels for G-6-major-chord-0.mid
# Processing 203/255: G-6-major-chord-1.mid
# Created 6 variations with different noise levels for G-6-major-chord-1.mid
# Processing 204/255: G-6-major-chord-2.mid
# Created 6 variations with different noise levels for G-6-major-chord-2.mid
# Processing 205/255: Ab-6-major-chord-0.mid
# Created 6 variations with different noise levels for Ab-6-major-chord-0.mid
# Processing 206/255: Ab-6-major-chord-1.mid
# Created 6 variations with different noise levels for Ab-6-major-chord-1.mid
# Processing 207/255: Ab-6-major-chord-2.mid
# Created 6 variations with different noise levels for Ab-6-major-chord-2.mid
# Processing 208/255: A-6-major-chord-0.mid
# Created 6 variations with different noise levels for A-6-major-chord-0.mid
# Processing 209/255: A-6-major-chord-1.mid
# Created 6 variations with different noise levels for A-6-major-chord-1.mid
# Processing 210/255: A-6-major-chord-2.mid
# Created 6 variations with different noise levels for A-6-major-chord-2.mid
# Processing 211/255: Bb-6-major-chord-0.mid
# Created 6 variations with different noise levels for Bb-6-major-chord-0.mid
# Processing 212/255: Bb-6-major-chord-1.mid
# Created 6 variations with different noise levels for Bb-6-major-chord-1.mid
# Processing 213/255: Bb-6-major-chord-2.mid
# Created 6 variations with different noise levels for Bb-6-major-chord-2.mid
# Processing 214/255: B-6-major-chord-0.mid
# Created 6 variations with different noise levels for B-6-major-chord-0.mid
# Processing 215/255: B-6-major-chord-1.mid
# Created 6 variations with different noise levels for B-6-major-chord-1.mid
# Processing 216/255: B-6-major-chord-2.mid
# Created 6 variations with different noise levels for B-6-major-chord-2.mid
# Processing 217/255: C-7-major-chord-0.mid
# Created 6 variations with different noise levels for C-7-major-chord-0.mid
# Processing 218/255: C-7-major-chord-1.mid
# Created 6 variations with different noise levels for C-7-major-chord-1.mid
# Processing 219/255: C-7-major-chord-2.mid
# Created 6 variations with different noise levels for C-7-major-chord-2.mid
# Processing 220/255: C#-7-major-chord-0.mid
# Created 6 variations with different noise levels for C#-7-major-chord-0.mid
# Processing 221/255: C#-7-major-chord-1.mid
# Created 6 variations with different noise levels for C#-7-major-chord-1.mid
# Processing 222/255: C#-7-major-chord-2.mid
# Created 6 variations with different noise levels for C#-7-major-chord-2.mid
# Processing 223/255: D-7-major-chord-0.mid
# Created 6 variations with different noise levels for D-7-major-chord-0.mid
# Processing 224/255: D-7-major-chord-1.mid
# Created 6 variations with different noise levels for D-7-major-chord-1.mid
# Processing 225/255: D-7-major-chord-2.mid
# Created 6 variations with different noise levels for D-7-major-chord-2.mid
# Processing 226/255: Eb-7-major-chord-0.mid
# Created 6 variations with different noise levels for Eb-7-major-chord-0.mid
# Processing 227/255: Eb-7-major-chord-1.mid
# Created 6 variations with different noise levels for Eb-7-major-chord-1.mid
# Processing 228/255: Eb-7-major-chord-2.mid
# Created 6 variations with different noise levels for Eb-7-major-chord-2.mid
# Processing 229/255: E-7-major-chord-0.mid
# Created 6 variations with different noise levels for E-7-major-chord-0.mid
# Processing 230/255: E-7-major-chord-1.mid
# Created 6 variations with different noise levels for E-7-major-chord-1.mid
# Processing 231/255: E-7-major-chord-2.mid
# Created 6 variations with different noise levels for E-7-major-chord-2.mid
# Processing 232/255: F-7-major-chord-0.mid
# Created 6 variations with different noise levels for F-7-major-chord-0.mid
# Processing 233/255: F-7-major-chord-1.mid
# Created 6 variations with different noise levels for F-7-major-chord-1.mid
# Processing 234/255: F-7-major-chord-2.mid
# Created 6 variations with different noise levels for F-7-major-chord-2.mid
# Processing 235/255: F#-7-major-chord-0.mid
# Created 6 variations with different noise levels for F#-7-major-chord-0.mid
# Processing 236/255: F#-7-major-chord-1.mid
# Created 6 variations with different noise levels for F#-7-major-chord-1.mid
# Processing 237/255: F#-7-major-chord-2.mid
# Created 6 variations with different noise levels for F#-7-major-chord-2.mid
# Processing 238/255: G-7-major-chord-0.mid
# Created 6 variations with different noise levels for G-7-major-chord-0.mid
# Processing 239/255: G-7-major-chord-1.mid
# Created 6 variations with different noise levels for G-7-major-chord-1.mid
# Processing 240/255: G-7-major-chord-2.mid
# Created 6 variations with different noise levels for G-7-major-chord-2.mid
# Processing 241/255: Ab-7-major-chord-0.mid
# Created 6 variations with different noise levels for Ab-7-major-chord-0.mid
# Processing 242/255: Ab-7-major-chord-1.mid
# Created 6 variations with different noise levels for Ab-7-major-chord-1.mid
# Processing 243/255: Ab-7-major-chord-2.mid
# Created 6 variations with different noise levels for Ab-7-major-chord-2.mid
# Processing 244/255: A-7-major-chord-0.mid
# Created 6 variations with different noise levels for A-7-major-chord-0.mid
# Processing 245/255: A-7-major-chord-1.mid
# Created 6 variations with different noise levels for A-7-major-chord-1.mid
# Processing 246/255: A-7-major-chord-2.mid
# Created 6 variations with different noise levels for A-7-major-chord-2.mid
# Processing 247/255: Bb-7-major-chord-0.mid
# Created 6 variations with different noise levels for Bb-7-major-chord-0.mid
# Processing 248/255: Bb-7-major-chord-1.mid
# Created 6 variations with different noise levels for Bb-7-major-chord-1.mid
# Processing 249/255: Bb-7-major-chord-2.mid
# Created 6 variations with different noise levels for Bb-7-major-chord-2.mid
# Processing 250/255: B-7-major-chord-0.mid
# Created 6 variations with different noise levels for B-7-major-chord-0.mid
# Processing 251/255: B-7-major-chord-1.mid
# Created 6 variations with different noise levels for B-7-major-chord-1.mid
# Processing 252/255: B-7-major-chord-2.mid
# Created 6 variations with different noise levels for B-7-major-chord-2.mid
# Processing 253/255: C-8-major-chord-0.mid
# Created 6 variations with different noise levels for C-8-major-chord-0.mid
# Processing 254/255: C-8-major-chord-1.mid
# Created 6 variations with different noise levels for C-8-major-chord-1.mid
# Processing 255/255: C-8-major-chord-2.mid
# Created 6 variations with different noise levels for C-8-major-chord-2.mid
#
# All done! Generated 255 major triad chord MIDI files and 1530 WAV files with varying noise levels.
# MIDI files are in: /content/drive/MyDrive/MusicGenerator/midi/chords/major
# WAV files are in: /content/drive/MyDrive/MusicGenerator/wav/chords/major

# %%
from midiutil import MIDIFile
import os
import subprocess
import numpy as np
from scipy.io import wavfile
from pathlib import Path
from google.colab import drive
import time as time_module  # Renamed to avoid conflict

# Mount Google Drive
drive.mount('/content/drive')

# Define the paths
base_dir = '/content/drive/MyDrive/MusicGenerator'
midi_dir = os.path.join(base_dir, "midi")
wav_dir = os.path.join(base_dir, "wav")

# Create directories if they don't exist
chord_type = "minor"  # Changed from "major" to "minor"
midi_chord_dir = os.path.join(midi_dir, "chords", chord_type)
wav_chord_dir = os.path.join(wav_dir, "chords", chord_type)

# Create necessary directories
Path(midi_chord_dir).mkdir(parents=True, exist_ok=True)
Path(wav_chord_dir).mkdir(parents=True, exist_ok=True)

print(f"Created MIDI directory: {midi_chord_dir}")
print(f"Created WAV directory: {wav_chord_dir}")

# Install required packages if needed
try:
    import scipy
except ImportError:
    print("Installing scipy...")
    subprocess.run(['pip', 'install', 'scipy'], check=True)
    from scipy.io import wavfile

noteArray = ["C", "C#", "D", "Eb", "E", "F", "F#", "G", "Ab", "A", "Bb", "B"]
octaveArray = [1, 2, 3, 4, 5, 6, 7, 8]  # Using the full octave range 1-8

# Generate note names with octaves (C-1, C-2, etc.)
nameArray = []
for octave in octaveArray:
    for note in noteArray:
        nameArray.append(f"{note}-{octave}")

# Minor triad parameters
offset1 = 3  # 3 semitones from root to flat third in a minor triad (changed from 4)
offset2 = 4  # 4 semitones from flat third to fifth in a minor triad (changed from 3)

# Function to add background noise to audio while preserving original volume
def add_noise(audio_data, noise_level):
    """
    Add background noise to audio at specified level without reducing original volume
    noise_level: 0 to 5, where 0 is no noise and 5 is maximum noise
    Returns: audio with added noise, maintaining original signal strength
    """
    # Scale noise level (0-5) to amplitude - SIGNIFICANTLY REDUCED
    # Reducing base amplitude by more than half and using a gentler exponential scale
    base_amplitude = 0.06  # Reduced from 0.15 (60% reduction)
    # Using a much gentler exponential factor (1.8 instead of 3)
    noise_amplitude = base_amplitude * (1.8 ** noise_level) / 32  # Much gentler scaling

    # This combination reduces noise by well over 50% at all levels

    # Convert to float64 for better precision during processing
    audio_float = audio_data.astype(np.float64)

    # Get the maximum value for the audio data type
    max_value = np.iinfo(audio_data.dtype).max

    # Check if audio is stereo (2D array) or mono (1D array)
    is_stereo = len(audio_data.shape) > 1 and audio_data.shape[1] > 1

    # Generate appropriate noise
    if is_stereo:
        # Handle stereo audio (separate noise for each channel)
        noise = np.random.normal(0, max_value * noise_amplitude, audio_data.shape).astype(np.float64)
    else:
        # Handle mono audio
        noise = np.random.normal(0, max_value * noise_amplitude, audio_data.shape[0]).astype(np.float64)

    # Calculate mixing ratio based on noise level
    # This ensures the original signal maintains its volume
    signal_weight = 1.0  # Keep original signal at 100%

    # Mix signal and noise with proper weighting
    mixed_audio = (signal_weight * audio_float) + noise

    # Clip to valid range for the data type
    mixed_audio_clipped = np.clip(mixed_audio, np.iinfo(audio_data.dtype).min, np.iinfo(audio_data.dtype).max)

    # Convert back to original data type
    return mixed_audio_clipped.astype(audio_data.dtype)

def createTriad(inversion, base, offset1, offset2):
    if(inversion==0):
        note1 = base
        note2 = base+offset1
        note3 = note2+offset2

    elif(inversion==1):
        note1 = base+offset1
        note2 = note1+offset2
        note3 = base+12

    elif(inversion==2):
        note1 = base+offset1+offset2
        note2 = base+12
        note3 = note2+offset1

    return note1, note2, note3

print("Generating minor triad chord MIDI files...")  # Changed from major to minor

# Counter for generated files
file_count = 0

# Process all notes in all octaves without limiting
for q, j in zip(nameArray, range(24,109)):
    noteName = q
    base = j

    for h in range(0, 3):  # Loop through all 3 inversions
        inversion = h
        appendInversion = "-"+str(inversion)

        note1, note2, note3 = createTriad(inversion, base, offset1, offset2)
        degrees = [note1, note2, note3]

        track    = 0
        channel  = 0
        time_pos = 0    # In beats (renamed from 'time' to avoid conflict)
        duration = 1    # In beats
        tempo    = 60   # In BPM
        volume   = 100  # 0-127, as per the MIDI standard

        MyMIDI = MIDIFile(1)  # One track
        MyMIDI.addTempo(track, time_pos, tempo)

        # Generate chord (all notes played simultaneously)
        for pitch in degrees:
            MyMIDI.addNote(track, channel, pitch, time_pos, duration, volume)

        midiName = noteName+'-'+chord_type+'-chord'+appendInversion+".mid"
        midi_filename = os.path.join(midi_chord_dir, midiName)

        with open(midi_filename, "wb") as output_file:
            MyMIDI.writeFile(output_file)
            file_count += 1

            # Print progress every 10 files
            if file_count % 10 == 0:
                print(f"Generated {file_count} MIDI files...")

print(f"Completed! Generated {file_count} minor triad chord MIDI files.")  # Changed from major to minor

# Install timidity if not already installed
try:
    subprocess.run(['which', 'timidity'], check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("TiMidity++ is already installed.")
except subprocess.CalledProcessError:
    print("Installing TiMidity++...")
    subprocess.run(['apt-get', 'update'], check=True)
    subprocess.run(['apt-get', 'install', '-y', 'timidity'], check=True)
    print("TiMidity++ installed successfully.")

# Convert MIDI files to WAV with different noise levels
print("\nConverting MIDI files to WAV format with varying noise levels (0-5)...")
wav_count = 0

# Get all MIDI files in the chord directory
midi_files = [f for f in os.listdir(midi_chord_dir) if f.endswith('.mid')]
total_midi_files = len(midi_files)
total_conversions = total_midi_files * 6  # 6 versions of each file (noise levels 0-5)

for idx, midi_file in enumerate(midi_files):
    midi_path = os.path.join(midi_chord_dir, midi_file)
    base_name = Path(midi_file).stem

    print(f"Processing {idx+1}/{total_midi_files}: {midi_file}")

    # First, convert to WAV without noise (temp file)
    temp_wav_path = os.path.join('/tmp', f"{base_name}_temp.wav")

    try:
        # Run timidity with a timeout to prevent hanging
        # Increase the volume of the MIDI files when converting to make them more prominent
        timidity_process = subprocess.run(
            ['timidity', midi_path, '-Ow1', '-s', '16kHz', '-A', '200', '-o', temp_wav_path],
            stdout=subprocess.PIPE, stderr=subprocess.PIPE,
            timeout=10  # Set a 10-second timeout for conversion
        )

        # Check if the temp file was created
        if not os.path.exists(temp_wav_path):
            print(f"Warning: Failed to create WAV file for {midi_file}")
            continue

        # Read the WAV file
        sample_rate, audio_data = wavfile.read(temp_wav_path)

        # Create versions with different noise levels
        for noise_level in range(6):  # 0 to 5
            # Add appropriate level of noise
            if noise_level == 0:
                # No noise for level 0
                noisy_audio = audio_data
            else:
                # Add increasing levels of noise
                noisy_audio = add_noise(audio_data, noise_level)

            # Save to final WAV file with noise level in filename
            wav_file = os.path.join(wav_chord_dir, f"{base_name}_noise{noise_level}.wav")
            wavfile.write(wav_file, sample_rate, noisy_audio)
            wav_count += 1

        # Success message for this file
        print(f"Created 6 variations with different noise levels for {midi_file}")

    except subprocess.TimeoutExpired:
        print(f"Warning: Conversion timeout for {midi_file}")
    except Exception as e:
        print(f"Error processing {midi_file}: {str(e)}")

    # Clean up temp file
    if os.path.exists(temp_wav_path):
        os.remove(temp_wav_path)

    # Add a small delay to prevent overwhelming the system
    time_module.sleep(0.1)  # Using the renamed time module

print(f"\nAll done! Generated {file_count} minor triad chord MIDI files and {wav_count} WAV files with varying noise levels.")  # Changed from major to minor
print(f"MIDI files are in: {midi_chord_dir}")
print(f"WAV files are in: {wav_chord_dir}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Created MIDI directory: /content/drive/MyDrive/MusicGenerator/midi/chords/minor
# Created WAV directory: /content/drive/MyDrive/MusicGenerator/wav/chords/minor
# Generating minor triad chord MIDI files...
# Generated 10 MIDI files...
# Generated 20 MIDI files...
# Generated 30 MIDI files...
# Generated 40 MIDI files...
# Generated 50 MIDI files...
# Generated 60 MIDI files...
# Generated 70 MIDI files...
# Generated 80 MIDI files...
# Generated 90 MIDI files...
# Generated 100 MIDI files...
# Generated 110 MIDI files...
# Generated 120 MIDI files...
# Generated 130 MIDI files...
# Generated 140 MIDI files...
# Generated 150 MIDI files...
# Generated 160 MIDI files...
# Generated 170 MIDI files...
# Generated 180 MIDI files...
# Generated 190 MIDI files...
# Generated 200 MIDI files...
# Generated 210 MIDI files...
# Generated 220 MIDI files...
# Generated 230 MIDI files...
# Generated 240 MIDI files...
# Generated 250 MIDI files...
# Completed! Generated 255 minor triad chord MIDI files.
# TiMidity++ is already installed.
#
# Converting MIDI files to WAV format with varying noise levels (0-5)...
# Processing 1/255: C-1-minor-chord-1.mid
# Created 6 variations with different noise levels for C-1-minor-chord-1.mid
# Processing 2/255: C-1-minor-chord-0.mid
# Created 6 variations with different noise levels for C-1-minor-chord-0.mid
# Processing 3/255: D-1-minor-chord-0.mid
# Created 6 variations with different noise levels for D-1-minor-chord-0.mid
# Processing 4/255: D-1-minor-chord-2.mid
# Created 6 variations with different noise levels for D-1-minor-chord-2.mid
# Processing 5/255: C#-1-minor-chord-0.mid
# Created 6 variations with different noise levels for C#-1-minor-chord-0.mid
# Processing 6/255: C-1-minor-chord-2.mid
# Created 6 variations with different noise levels for C-1-minor-chord-2.mid
# Processing 7/255: C#-1-minor-chord-2.mid
# Created 6 variations with different noise levels for C#-1-minor-chord-2.mid
# Processing 8/255: D-1-minor-chord-1.mid
# Created 6 variations with different noise levels for D-1-minor-chord-1.mid
# Processing 9/255: Eb-1-minor-chord-1.mid
# Created 6 variations with different noise levels for Eb-1-minor-chord-1.mid
# Processing 10/255: C#-1-minor-chord-1.mid
# Created 6 variations with different noise levels for C#-1-minor-chord-1.mid
# Processing 11/255: Eb-1-minor-chord-0.mid
# Created 6 variations with different noise levels for Eb-1-minor-chord-0.mid
# Processing 12/255: Eb-1-minor-chord-2.mid
# Created 6 variations with different noise levels for Eb-1-minor-chord-2.mid
# Processing 13/255: E-1-minor-chord-0.mid
# Created 6 variations with different noise levels for E-1-minor-chord-0.mid
# Processing 14/255: E-1-minor-chord-1.mid
# Created 6 variations with different noise levels for E-1-minor-chord-1.mid
# Processing 15/255: E-1-minor-chord-2.mid
# Created 6 variations with different noise levels for E-1-minor-chord-2.mid
# Processing 16/255: F-1-minor-chord-1.mid
# Created 6 variations with different noise levels for F-1-minor-chord-1.mid
# Processing 17/255: F#-1-minor-chord-0.mid
# Created 6 variations with different noise levels for F#-1-minor-chord-0.mid
# Processing 18/255: F-1-minor-chord-0.mid
# Created 6 variations with different noise levels for F-1-minor-chord-0.mid
# Processing 19/255: F-1-minor-chord-2.mid
# Created 6 variations with different noise levels for F-1-minor-chord-2.mid
# Processing 20/255: F#-1-minor-chord-1.mid
# Created 6 variations with different noise levels for F#-1-minor-chord-1.mid
# Processing 21/255: F#-1-minor-chord-2.mid
# Created 6 variations with different noise levels for F#-1-minor-chord-2.mid
# Processing 22/255: G-1-minor-chord-0.mid
# Created 6 variations with different noise levels for G-1-minor-chord-0.mid
# Processing 23/255: G-1-minor-chord-1.mid
# Created 6 variations with different noise levels for G-1-minor-chord-1.mid
# Processing 24/255: G-1-minor-chord-2.mid
# Created 6 variations with different noise levels for G-1-minor-chord-2.mid
# Processing 25/255: Ab-1-minor-chord-0.mid
# Created 6 variations with different noise levels for Ab-1-minor-chord-0.mid
# Processing 26/255: Ab-1-minor-chord-1.mid
# Created 6 variations with different noise levels for Ab-1-minor-chord-1.mid
# Processing 27/255: Ab-1-minor-chord-2.mid
# Created 6 variations with different noise levels for Ab-1-minor-chord-2.mid
# Processing 28/255: A-1-minor-chord-1.mid
# Created 6 variations with different noise levels for A-1-minor-chord-1.mid
# Processing 29/255: A-1-minor-chord-0.mid
# Created 6 variations with different noise levels for A-1-minor-chord-0.mid
# Processing 30/255: A-1-minor-chord-2.mid
# Created 6 variations with different noise levels for A-1-minor-chord-2.mid
# Processing 31/255: Bb-1-minor-chord-0.mid
# Created 6 variations with different noise levels for Bb-1-minor-chord-0.mid
# Processing 32/255: Bb-1-minor-chord-1.mid
# Created 6 variations with different noise levels for Bb-1-minor-chord-1.mid
# Processing 33/255: Bb-1-minor-chord-2.mid
# Created 6 variations with different noise levels for Bb-1-minor-chord-2.mid
# Processing 34/255: B-1-minor-chord-0.mid
# Created 6 variations with different noise levels for B-1-minor-chord-0.mid
# Processing 35/255: B-1-minor-chord-1.mid
# Created 6 variations with different noise levels for B-1-minor-chord-1.mid
# Processing 36/255: B-1-minor-chord-2.mid
# Created 6 variations with different noise levels for B-1-minor-chord-2.mid
# Processing 37/255: C-2-minor-chord-0.mid
# Created 6 variations with different noise levels for C-2-minor-chord-0.mid
# Processing 38/255: C-2-minor-chord-1.mid
# Created 6 variations with different noise levels for C-2-minor-chord-1.mid
# Processing 39/255: C-2-minor-chord-2.mid
# Created 6 variations with different noise levels for C-2-minor-chord-2.mid
# Processing 40/255: C#-2-minor-chord-0.mid
# Created 6 variations with different noise levels for C#-2-minor-chord-0.mid
# Processing 41/255: C#-2-minor-chord-1.mid
# Created 6 variations with different noise levels for C#-2-minor-chord-1.mid
# Processing 42/255: D-2-minor-chord-0.mid
# Created 6 variations with different noise levels for D-2-minor-chord-0.mid
# Processing 43/255: C#-2-minor-chord-2.mid
# Created 6 variations with different noise levels for C#-2-minor-chord-2.mid
# Processing 44/255: D-2-minor-chord-1.mid
# Created 6 variations with different noise levels for D-2-minor-chord-1.mid
# Processing 45/255: D-2-minor-chord-2.mid
# Created 6 variations with different noise levels for D-2-minor-chord-2.mid
# Processing 46/255: Eb-2-minor-chord-0.mid
# Created 6 variations with different noise levels for Eb-2-minor-chord-0.mid
# Processing 47/255: Eb-2-minor-chord-1.mid
# Created 6 variations with different noise levels for Eb-2-minor-chord-1.mid
# Processing 48/255: Eb-2-minor-chord-2.mid
# Created 6 variations with different noise levels for Eb-2-minor-chord-2.mid
# Processing 49/255: E-2-minor-chord-0.mid
# Created 6 variations with different noise levels for E-2-minor-chord-0.mid
# Processing 50/255: E-2-minor-chord-1.mid
# Created 6 variations with different noise levels for E-2-minor-chord-1.mid
# Processing 51/255: E-2-minor-chord-2.mid
# Created 6 variations with different noise levels for E-2-minor-chord-2.mid
# Processing 52/255: F-2-minor-chord-0.mid
# Created 6 variations with different noise levels for F-2-minor-chord-0.mid
# Processing 53/255: F-2-minor-chord-1.mid
# Created 6 variations with different noise levels for F-2-minor-chord-1.mid
# Processing 54/255: F#-2-minor-chord-0.mid
# Created 6 variations with different noise levels for F#-2-minor-chord-0.mid
# Processing 55/255: F-2-minor-chord-2.mid
# Created 6 variations with different noise levels for F-2-minor-chord-2.mid
# Processing 56/255: F#-2-minor-chord-2.mid
# Created 6 variations with different noise levels for F#-2-minor-chord-2.mid
# Processing 57/255: G-2-minor-chord-1.mid
# Created 6 variations with different noise levels for G-2-minor-chord-1.mid
# Processing 58/255: G-2-minor-chord-2.mid
# Created 6 variations with different noise levels for G-2-minor-chord-2.mid
# Processing 59/255: F#-2-minor-chord-1.mid
# Created 6 variations with different noise levels for F#-2-minor-chord-1.mid
# Processing 60/255: G-2-minor-chord-0.mid
# Created 6 variations with different noise levels for G-2-minor-chord-0.mid
# Processing 61/255: Ab-2-minor-chord-0.mid
# Created 6 variations with different noise levels for Ab-2-minor-chord-0.mid
# Processing 62/255: Ab-2-minor-chord-1.mid
# Created 6 variations with different noise levels for Ab-2-minor-chord-1.mid
# Processing 63/255: Ab-2-minor-chord-2.mid
# Created 6 variations with different noise levels for Ab-2-minor-chord-2.mid
# Processing 64/255: A-2-minor-chord-0.mid
# Created 6 variations with different noise levels for A-2-minor-chord-0.mid
# Processing 65/255: A-2-minor-chord-2.mid
# Created 6 variations with different noise levels for A-2-minor-chord-2.mid
# Processing 66/255: Bb-2-minor-chord-0.mid
# Created 6 variations with different noise levels for Bb-2-minor-chord-0.mid
# Processing 67/255: Bb-2-minor-chord-1.mid
# Created 6 variations with different noise levels for Bb-2-minor-chord-1.mid
# Processing 68/255: A-2-minor-chord-1.mid
# Created 6 variations with different noise levels for A-2-minor-chord-1.mid
# Processing 69/255: Bb-2-minor-chord-2.mid
# Created 6 variations with different noise levels for Bb-2-minor-chord-2.mid
# Processing 70/255: B-2-minor-chord-2.mid
# Created 6 variations with different noise levels for B-2-minor-chord-2.mid
# Processing 71/255: B-2-minor-chord-0.mid
# Created 6 variations with different noise levels for B-2-minor-chord-0.mid
# Processing 72/255: B-2-minor-chord-1.mid
# Created 6 variations with different noise levels for B-2-minor-chord-1.mid
# Processing 73/255: C-3-minor-chord-1.mid
# Created 6 variations with different noise levels for C-3-minor-chord-1.mid
# Processing 74/255: C-3-minor-chord-0.mid
# Created 6 variations with different noise levels for C-3-minor-chord-0.mid
# Processing 75/255: C-3-minor-chord-2.mid
# Created 6 variations with different noise levels for C-3-minor-chord-2.mid
# Processing 76/255: C#-3-minor-chord-0.mid
# Created 6 variations with different noise levels for C#-3-minor-chord-0.mid
# Processing 77/255: D-3-minor-chord-0.mid
# Created 6 variations with different noise levels for D-3-minor-chord-0.mid
# Processing 78/255: C#-3-minor-chord-1.mid
# Created 6 variations with different noise levels for C#-3-minor-chord-1.mid
# Processing 79/255: C#-3-minor-chord-2.mid
# Created 6 variations with different noise levels for C#-3-minor-chord-2.mid
# Processing 80/255: D-3-minor-chord-1.mid
# Created 6 variations with different noise levels for D-3-minor-chord-1.mid
# Processing 81/255: D-3-minor-chord-2.mid
# Created 6 variations with different noise levels for D-3-minor-chord-2.mid
# Processing 82/255: Eb-3-minor-chord-0.mid
# Created 6 variations with different noise levels for Eb-3-minor-chord-0.mid
# Processing 83/255: Eb-3-minor-chord-2.mid
# Created 6 variations with different noise levels for Eb-3-minor-chord-2.mid
# Processing 84/255: E-3-minor-chord-0.mid
# Created 6 variations with different noise levels for E-3-minor-chord-0.mid
# Processing 85/255: Eb-3-minor-chord-1.mid
# Created 6 variations with different noise levels for Eb-3-minor-chord-1.mid
# Processing 86/255: E-3-minor-chord-1.mid
# Created 6 variations with different noise levels for E-3-minor-chord-1.mid
# Processing 87/255: E-3-minor-chord-2.mid
# Created 6 variations with different noise levels for E-3-minor-chord-2.mid
# Processing 88/255: F-3-minor-chord-0.mid
# Created 6 variations with different noise levels for F-3-minor-chord-0.mid
# Processing 89/255: F-3-minor-chord-2.mid
# Created 6 variations with different noise levels for F-3-minor-chord-2.mid
# Processing 90/255: F#-3-minor-chord-0.mid
# Created 6 variations with different noise levels for F#-3-minor-chord-0.mid
# Processing 91/255: F-3-minor-chord-1.mid
# Created 6 variations with different noise levels for F-3-minor-chord-1.mid
# Processing 92/255: F#-3-minor-chord-1.mid
# Created 6 variations with different noise levels for F#-3-minor-chord-1.mid
# Processing 93/255: F#-3-minor-chord-2.mid
# Created 6 variations with different noise levels for F#-3-minor-chord-2.mid
# Processing 94/255: Ab-3-minor-chord-0.mid
# Created 6 variations with different noise levels for Ab-3-minor-chord-0.mid
# Processing 95/255: G-3-minor-chord-1.mid
# Created 6 variations with different noise levels for G-3-minor-chord-1.mid
# Processing 96/255: Ab-3-minor-chord-1.mid
# Created 6 variations with different noise levels for Ab-3-minor-chord-1.mid
# Processing 97/255: G-3-minor-chord-2.mid
# Created 6 variations with different noise levels for G-3-minor-chord-2.mid
# Processing 98/255: G-3-minor-chord-0.mid
# Created 6 variations with different noise levels for G-3-minor-chord-0.mid
# Processing 99/255: Ab-3-minor-chord-2.mid
# Created 6 variations with different noise levels for Ab-3-minor-chord-2.mid
# Processing 100/255: A-3-minor-chord-0.mid
# Created 6 variations with different noise levels for A-3-minor-chord-0.mid
# Processing 101/255: A-3-minor-chord-1.mid
# Created 6 variations with different noise levels for A-3-minor-chord-1.mid
# Processing 102/255: A-3-minor-chord-2.mid
# Created 6 variations with different noise levels for A-3-minor-chord-2.mid
# Processing 103/255: Bb-3-minor-chord-1.mid
# Created 6 variations with different noise levels for Bb-3-minor-chord-1.mid
# Processing 104/255: Bb-3-minor-chord-2.mid
# Created 6 variations with different noise levels for Bb-3-minor-chord-2.mid
# Processing 105/255: B-3-minor-chord-1.mid
# Created 6 variations with different noise levels for B-3-minor-chord-1.mid
# Processing 106/255: B-3-minor-chord-0.mid
# Created 6 variations with different noise levels for B-3-minor-chord-0.mid
# Processing 107/255: Bb-3-minor-chord-0.mid
# Created 6 variations with different noise levels for Bb-3-minor-chord-0.mid
# Processing 108/255: C-4-minor-chord-0.mid
# Created 6 variations with different noise levels for C-4-minor-chord-0.mid
# Processing 109/255: B-3-minor-chord-2.mid
# Created 6 variations with different noise levels for B-3-minor-chord-2.mid
# Processing 110/255: C-4-minor-chord-1.mid
# Created 6 variations with different noise levels for C-4-minor-chord-1.mid
# Processing 111/255: C#-4-minor-chord-0.mid
# Created 6 variations with different noise levels for C#-4-minor-chord-0.mid
# Processing 112/255: C#-4-minor-chord-1.mid
# Created 6 variations with different noise levels for C#-4-minor-chord-1.mid
# Processing 113/255: C#-4-minor-chord-2.mid
# Created 6 variations with different noise levels for C#-4-minor-chord-2.mid
# Processing 114/255: D-4-minor-chord-0.mid
# Created 6 variations with different noise levels for D-4-minor-chord-0.mid
# Processing 115/255: C-4-minor-chord-2.mid
# Created 6 variations with different noise levels for C-4-minor-chord-2.mid
# Processing 116/255: Eb-4-minor-chord-1.mid
# Created 6 variations with different noise levels for Eb-4-minor-chord-1.mid
# Processing 117/255: D-4-minor-chord-2.mid
# Created 6 variations with different noise levels for D-4-minor-chord-2.mid
# Processing 118/255: Eb-4-minor-chord-0.mid
# Created 6 variations with different noise levels for Eb-4-minor-chord-0.mid
# Processing 119/255: D-4-minor-chord-1.mid
# Created 6 variations with different noise levels for D-4-minor-chord-1.mid
# Processing 120/255: Eb-4-minor-chord-2.mid
# Created 6 variations with different noise levels for Eb-4-minor-chord-2.mid
# Processing 121/255: E-4-minor-chord-1.mid
# Created 6 variations with different noise levels for E-4-minor-chord-1.mid
# Processing 122/255: E-4-minor-chord-2.mid
# Created 6 variations with different noise levels for E-4-minor-chord-2.mid
# Processing 123/255: F-4-minor-chord-0.mid
# Created 6 variations with different noise levels for F-4-minor-chord-0.mid
# Processing 124/255: F-4-minor-chord-2.mid
# Created 6 variations with different noise levels for F-4-minor-chord-2.mid
# Processing 125/255: E-4-minor-chord-0.mid
# Created 6 variations with different noise levels for E-4-minor-chord-0.mid
# Processing 126/255: F-4-minor-chord-1.mid
# Created 6 variations with different noise levels for F-4-minor-chord-1.mid
# Processing 127/255: F#-4-minor-chord-0.mid
# Created 6 variations with different noise levels for F#-4-minor-chord-0.mid
# Processing 128/255: F#-4-minor-chord-1.mid
# Created 6 variations with different noise levels for F#-4-minor-chord-1.mid
# Processing 129/255: F#-4-minor-chord-2.mid
# Created 6 variations with different noise levels for F#-4-minor-chord-2.mid
# Processing 130/255: G-4-minor-chord-0.mid
# Created 6 variations with different noise levels for G-4-minor-chord-0.mid
# Processing 131/255: G-4-minor-chord-1.mid
# Created 6 variations with different noise levels for G-4-minor-chord-1.mid
# Processing 132/255: G-4-minor-chord-2.mid
# Created 6 variations with different noise levels for G-4-minor-chord-2.mid
# Processing 133/255: A-4-minor-chord-0.mid
# Created 6 variations with different noise levels for A-4-minor-chord-0.mid
# Processing 134/255: Ab-4-minor-chord-1.mid
# Created 6 variations with different noise levels for Ab-4-minor-chord-1.mid
# Processing 135/255: Ab-4-minor-chord-0.mid
# Created 6 variations with different noise levels for Ab-4-minor-chord-0.mid
# Processing 136/255: Ab-4-minor-chord-2.mid
# Created 6 variations with different noise levels for Ab-4-minor-chord-2.mid
# Processing 137/255: A-4-minor-chord-2.mid
# Created 6 variations with different noise levels for A-4-minor-chord-2.mid
# Processing 138/255: A-4-minor-chord-1.mid
# Created 6 variations with different noise levels for A-4-minor-chord-1.mid
# Processing 139/255: Bb-4-minor-chord-0.mid
# Created 6 variations with different noise levels for Bb-4-minor-chord-0.mid
# Processing 140/255: Bb-4-minor-chord-1.mid
# Created 6 variations with different noise levels for Bb-4-minor-chord-1.mid
# Processing 141/255: B-4-minor-chord-0.mid
# Created 6 variations with different noise levels for B-4-minor-chord-0.mid
# Processing 142/255: Bb-4-minor-chord-2.mid
# Created 6 variations with different noise levels for Bb-4-minor-chord-2.mid
# Processing 143/255: B-4-minor-chord-1.mid
# Created 6 variations with different noise levels for B-4-minor-chord-1.mid
# Processing 144/255: C-5-minor-chord-0.mid
# Created 6 variations with different noise levels for C-5-minor-chord-0.mid
# Processing 145/255: C-5-minor-chord-1.mid
# Created 6 variations with different noise levels for C-5-minor-chord-1.mid
# Processing 146/255: B-4-minor-chord-2.mid
# Created 6 variations with different noise levels for B-4-minor-chord-2.mid
# Processing 147/255: C-5-minor-chord-2.mid
# Created 6 variations with different noise levels for C-5-minor-chord-2.mid
# Processing 148/255: C#-5-minor-chord-0.mid
# Created 6 variations with different noise levels for C#-5-minor-chord-0.mid
# Processing 149/255: C#-5-minor-chord-1.mid
# Created 6 variations with different noise levels for C#-5-minor-chord-1.mid
# Processing 150/255: C#-5-minor-chord-2.mid
# Created 6 variations with different noise levels for C#-5-minor-chord-2.mid
# Processing 151/255: D-5-minor-chord-0.mid
# Created 6 variations with different noise levels for D-5-minor-chord-0.mid
# Processing 152/255: Eb-5-minor-chord-0.mid
# Created 6 variations with different noise levels for Eb-5-minor-chord-0.mid
# Processing 153/255: D-5-minor-chord-2.mid
# Created 6 variations with different noise levels for D-5-minor-chord-2.mid
# Processing 154/255: D-5-minor-chord-1.mid
# Created 6 variations with different noise levels for D-5-minor-chord-1.mid
# Processing 155/255: E-5-minor-chord-0.mid
# Created 6 variations with different noise levels for E-5-minor-chord-0.mid
# Processing 156/255: Eb-5-minor-chord-2.mid
# Created 6 variations with different noise levels for Eb-5-minor-chord-2.mid
# Processing 157/255: Eb-5-minor-chord-1.mid
# Created 6 variations with different noise levels for Eb-5-minor-chord-1.mid
# Processing 158/255: E-5-minor-chord-1.mid
# Created 6 variations with different noise levels for E-5-minor-chord-1.mid
# Processing 159/255: E-5-minor-chord-2.mid
# Created 6 variations with different noise levels for E-5-minor-chord-2.mid
# Processing 160/255: F-5-minor-chord-0.mid
# Created 6 variations with different noise levels for F-5-minor-chord-0.mid
# Processing 161/255: F-5-minor-chord-2.mid
# Created 6 variations with different noise levels for F-5-minor-chord-2.mid
# Processing 162/255: F-5-minor-chord-1.mid
# Created 6 variations with different noise levels for F-5-minor-chord-1.mid
# Processing 163/255: F#-5-minor-chord-1.mid
# Created 6 variations with different noise levels for F#-5-minor-chord-1.mid
# Processing 164/255: F#-5-minor-chord-0.mid
# Created 6 variations with different noise levels for F#-5-minor-chord-0.mid
# Processing 165/255: G-5-minor-chord-2.mid
# Created 6 variations with different noise levels for G-5-minor-chord-2.mid
# Processing 166/255: G-5-minor-chord-0.mid
# Created 6 variations with different noise levels for G-5-minor-chord-0.mid
# Processing 167/255: F#-5-minor-chord-2.mid
# Created 6 variations with different noise levels for F#-5-minor-chord-2.mid
# Processing 168/255: G-5-minor-chord-1.mid
# Created 6 variations with different noise levels for G-5-minor-chord-1.mid
# Processing 169/255: Ab-5-minor-chord-0.mid
# Created 6 variations with different noise levels for Ab-5-minor-chord-0.mid
# Processing 170/255: Ab-5-minor-chord-2.mid
# Created 6 variations with different noise levels for Ab-5-minor-chord-2.mid
# Processing 171/255: Ab-5-minor-chord-1.mid
# Created 6 variations with different noise levels for Ab-5-minor-chord-1.mid
# Processing 172/255: A-5-minor-chord-1.mid
# Created 6 variations with different noise levels for A-5-minor-chord-1.mid
# Processing 173/255: A-5-minor-chord-0.mid
# Created 6 variations with different noise levels for A-5-minor-chord-0.mid
# Processing 174/255: A-5-minor-chord-2.mid
# Created 6 variations with different noise levels for A-5-minor-chord-2.mid
# Processing 175/255: Bb-5-minor-chord-0.mid
# Created 6 variations with different noise levels for Bb-5-minor-chord-0.mid
# Processing 176/255: Bb-5-minor-chord-1.mid
# Created 6 variations with different noise levels for Bb-5-minor-chord-1.mid
# Processing 177/255: B-5-minor-chord-0.mid
# Created 6 variations with different noise levels for B-5-minor-chord-0.mid
# Processing 178/255: Bb-5-minor-chord-2.mid
# Created 6 variations with different noise levels for Bb-5-minor-chord-2.mid
# Processing 179/255: B-5-minor-chord-1.mid
# Created 6 variations with different noise levels for B-5-minor-chord-1.mid
# Processing 180/255: B-5-minor-chord-2.mid
# Created 6 variations with different noise levels for B-5-minor-chord-2.mid
# Processing 181/255: C#-6-minor-chord-2.mid
# Created 6 variations with different noise levels for C#-6-minor-chord-2.mid
# Processing 182/255: C#-6-minor-chord-0.mid
# Created 6 variations with different noise levels for C#-6-minor-chord-0.mid
# Processing 183/255: C-6-minor-chord-2.mid
# Created 6 variations with different noise levels for C-6-minor-chord-2.mid
# Processing 184/255: C-6-minor-chord-1.mid
# Created 6 variations with different noise levels for C-6-minor-chord-1.mid
# Processing 185/255: D-6-minor-chord-2.mid
# Created 6 variations with different noise levels for D-6-minor-chord-2.mid
# Processing 186/255: D-6-minor-chord-0.mid
# Created 6 variations with different noise levels for D-6-minor-chord-0.mid
# Processing 187/255: C#-6-minor-chord-1.mid
# Created 6 variations with different noise levels for C#-6-minor-chord-1.mid
# Processing 188/255: D-6-minor-chord-1.mid
# Created 6 variations with different noise levels for D-6-minor-chord-1.mid
# Processing 189/255: C-6-minor-chord-0.mid
# Created 6 variations with different noise levels for C-6-minor-chord-0.mid
# Processing 190/255: Eb-6-minor-chord-0.mid
# Created 6 variations with different noise levels for Eb-6-minor-chord-0.mid
# Processing 191/255: E-6-minor-chord-0.mid
# Created 6 variations with different noise levels for E-6-minor-chord-0.mid
# Processing 192/255: Eb-6-minor-chord-2.mid
# Created 6 variations with different noise levels for Eb-6-minor-chord-2.mid
# Processing 193/255: E-6-minor-chord-2.mid
# Created 6 variations with different noise levels for E-6-minor-chord-2.mid
# Processing 194/255: Eb-6-minor-chord-1.mid
# Created 6 variations with different noise levels for Eb-6-minor-chord-1.mid
# Processing 195/255: F-6-minor-chord-0.mid
# Created 6 variations with different noise levels for F-6-minor-chord-0.mid
# Processing 196/255: E-6-minor-chord-1.mid
# Created 6 variations with different noise levels for E-6-minor-chord-1.mid
# Processing 197/255: F-6-minor-chord-1.mid
# Created 6 variations with different noise levels for F-6-minor-chord-1.mid
# Processing 198/255: F#-6-minor-chord-0.mid
# Created 6 variations with different noise levels for F#-6-minor-chord-0.mid
# Processing 199/255: F-6-minor-chord-2.mid
# Created 6 variations with different noise levels for F-6-minor-chord-2.mid
# Processing 200/255: F#-6-minor-chord-1.mid
# Created 6 variations with different noise levels for F#-6-minor-chord-1.mid
# Processing 201/255: F#-6-minor-chord-2.mid
# Created 6 variations with different noise levels for F#-6-minor-chord-2.mid
# Processing 202/255: G-6-minor-chord-0.mid
# Created 6 variations with different noise levels for G-6-minor-chord-0.mid
# Processing 203/255: G-6-minor-chord-2.mid
# Created 6 variations with different noise levels for G-6-minor-chord-2.mid
# Processing 204/255: Ab-6-minor-chord-0.mid
# Created 6 variations with different noise levels for Ab-6-minor-chord-0.mid
# Processing 205/255: Ab-6-minor-chord-1.mid
# Created 6 variations with different noise levels for Ab-6-minor-chord-1.mid
# Processing 206/255: G-6-minor-chord-1.mid
# Created 6 variations with different noise levels for G-6-minor-chord-1.mid
# Processing 207/255: Ab-6-minor-chord-2.mid
# Created 6 variations with different noise levels for Ab-6-minor-chord-2.mid
# Processing 208/255: A-6-minor-chord-0.mid
# Created 6 variations with different noise levels for A-6-minor-chord-0.mid
# Processing 209/255: A-6-minor-chord-1.mid
# Created 6 variations with different noise levels for A-6-minor-chord-1.mid
# Processing 210/255: A-6-minor-chord-2.mid
# Created 6 variations with different noise levels for A-6-minor-chord-2.mid
# Processing 211/255: Bb-6-minor-chord-0.mid
# Created 6 variations with different noise levels for Bb-6-minor-chord-0.mid
# Processing 212/255: Bb-6-minor-chord-1.mid
# Created 6 variations with different noise levels for Bb-6-minor-chord-1.mid
# Processing 213/255: B-6-minor-chord-0.mid
# Created 6 variations with different noise levels for B-6-minor-chord-0.mid
# Processing 214/255: B-6-minor-chord-1.mid
# Created 6 variations with different noise levels for B-6-minor-chord-1.mid
# Processing 215/255: Bb-6-minor-chord-2.mid
# Created 6 variations with different noise levels for Bb-6-minor-chord-2.mid
# Processing 216/255: C-7-minor-chord-0.mid
# Created 6 variations with different noise levels for C-7-minor-chord-0.mid
# Processing 217/255: C-7-minor-chord-1.mid
# Created 6 variations with different noise levels for C-7-minor-chord-1.mid
# Processing 218/255: B-6-minor-chord-2.mid
# Created 6 variations with different noise levels for B-6-minor-chord-2.mid
# Processing 219/255: C-7-minor-chord-2.mid
# Created 6 variations with different noise levels for C-7-minor-chord-2.mid
# Processing 220/255: C#-7-minor-chord-1.mid
# Created 6 variations with different noise levels for C#-7-minor-chord-1.mid
# Processing 221/255: C#-7-minor-chord-0.mid
# Created 6 variations with different noise levels for C#-7-minor-chord-0.mid
# Processing 222/255: C#-7-minor-chord-2.mid
# Created 6 variations with different noise levels for C#-7-minor-chord-2.mid
# Processing 223/255: D-7-minor-chord-1.mid
# Created 6 variations with different noise levels for D-7-minor-chord-1.mid
# Processing 224/255: D-7-minor-chord-0.mid
# Created 6 variations with different noise levels for D-7-minor-chord-0.mid
# Processing 225/255: D-7-minor-chord-2.mid
# Created 6 variations with different noise levels for D-7-minor-chord-2.mid
# Processing 226/255: Eb-7-minor-chord-0.mid
# Created 6 variations with different noise levels for Eb-7-minor-chord-0.mid
# Processing 227/255: E-7-minor-chord-0.mid
# Created 6 variations with different noise levels for E-7-minor-chord-0.mid
# Processing 228/255: Eb-7-minor-chord-2.mid
# Created 6 variations with different noise levels for Eb-7-minor-chord-2.mid
# Processing 229/255: Eb-7-minor-chord-1.mid
# Created 6 variations with different noise levels for Eb-7-minor-chord-1.mid
# Processing 230/255: E-7-minor-chord-1.mid
# Created 6 variations with different noise levels for E-7-minor-chord-1.mid
# Processing 231/255: E-7-minor-chord-2.mid
# Created 6 variations with different noise levels for E-7-minor-chord-2.mid
# Processing 232/255: F-7-minor-chord-0.mid
# Created 6 variations with different noise levels for F-7-minor-chord-0.mid
# Processing 233/255: F-7-minor-chord-1.mid
# Created 6 variations with different noise levels for F-7-minor-chord-1.mid
# Processing 234/255: F#-7-minor-chord-0.mid
# Created 6 variations with different noise levels for F#-7-minor-chord-0.mid
# Processing 235/255: F#-7-minor-chord-2.mid
# Created 6 variations with different noise levels for F#-7-minor-chord-2.mid
# Processing 236/255: F-7-minor-chord-2.mid
# Created 6 variations with different noise levels for F-7-minor-chord-2.mid
# Processing 237/255: F#-7-minor-chord-1.mid
# Created 6 variations with different noise levels for F#-7-minor-chord-1.mid
# Processing 238/255: G-7-minor-chord-0.mid
# Created 6 variations with different noise levels for G-7-minor-chord-0.mid
# Processing 239/255: G-7-minor-chord-1.mid
# Created 6 variations with different noise levels for G-7-minor-chord-1.mid
# Processing 240/255: G-7-minor-chord-2.mid
# Created 6 variations with different noise levels for G-7-minor-chord-2.mid
# Processing 241/255: Ab-7-minor-chord-2.mid
# Created 6 variations with different noise levels for Ab-7-minor-chord-2.mid
# Processing 242/255: Ab-7-minor-chord-0.mid
# Created 6 variations with different noise levels for Ab-7-minor-chord-0.mid
# Processing 243/255: A-7-minor-chord-1.mid
# Created 6 variations with different noise levels for A-7-minor-chord-1.mid
# Processing 244/255: Ab-7-minor-chord-1.mid
# Created 6 variations with different noise levels for Ab-7-minor-chord-1.mid
# Processing 245/255: A-7-minor-chord-0.mid
# Created 6 variations with different noise levels for A-7-minor-chord-0.mid
# Processing 246/255: Bb-7-minor-chord-0.mid
# Created 6 variations with different noise levels for Bb-7-minor-chord-0.mid
# Processing 247/255: A-7-minor-chord-2.mid
# Created 6 variations with different noise levels for A-7-minor-chord-2.mid
# Processing 248/255: Bb-7-minor-chord-2.mid
# Created 6 variations with different noise levels for Bb-7-minor-chord-2.mid
# Processing 249/255: Bb-7-minor-chord-1.mid
# Created 6 variations with different noise levels for Bb-7-minor-chord-1.mid
# Processing 250/255: B-7-minor-chord-1.mid
# Created 6 variations with different noise levels for B-7-minor-chord-1.mid
# Processing 251/255: B-7-minor-chord-0.mid
# Created 6 variations with different noise levels for B-7-minor-chord-0.mid
# Processing 252/255: C-8-minor-chord-0.mid
# Created 6 variations with different noise levels for C-8-minor-chord-0.mid
# Processing 253/255: C-8-minor-chord-1.mid
# Created 6 variations with different noise levels for C-8-minor-chord-1.mid
# Processing 254/255: B-7-minor-chord-2.mid
# Created 6 variations with different noise levels for B-7-minor-chord-2.mid
# Processing 255/255: C-8-minor-chord-2.mid
# Created 6 variations with different noise levels for C-8-minor-chord-2.mid
#
# All done! Generated 255 minor triad chord MIDI files and 1530 WAV files with varying noise levels.
# MIDI files are in: /content/drive/MyDrive/MusicGenerator/midi/chords/minor
# WAV files are in: /content/drive/MyDrive/MusicGenerator/wav/chords/minor

# %%
#diminished

from midiutil import MIDIFile
import os
import subprocess
import numpy as np
from scipy.io import wavfile
from pathlib import Path
from google.colab import drive
import time as time_module  # Renamed to avoid conflict

# Mount Google Drive
drive.mount('/content/drive')

# Define the paths
base_dir = '/content/drive/MyDrive/MusicGenerator'
midi_dir = os.path.join(base_dir, "midi")
wav_dir = os.path.join(base_dir, "wav")

# Create directories if they don't exist
chord_type = "diminished"
midi_chord_dir = os.path.join(midi_dir, "chords", chord_type)
wav_chord_dir = os.path.join(wav_dir, "chords", chord_type)

# Create necessary directories
Path(midi_chord_dir).mkdir(parents=True, exist_ok=True)
Path(wav_chord_dir).mkdir(parents=True, exist_ok=True)

print(f"Created MIDI directory: {midi_chord_dir}")
print(f"Created WAV directory: {wav_chord_dir}")

# Install required packages if needed
try:
    import scipy
except ImportError:
    print("Installing scipy...")
    subprocess.run(['pip', 'install', 'scipy'], check=True)
    from scipy.io import wavfile

noteArray = ["C", "C#", "D", "Eb", "E", "F", "F#", "G", "Ab", "A", "Bb", "B"]
octaveArray = [1, 2, 3, 4, 5, 6, 7, 8]  # Using the full octave range 1-8

# Generate note names with octaves (C-1, C-2, etc.)
nameArray = []
for octave in octaveArray:
    for note in noteArray:
        nameArray.append(f"{note}-{octave}")

# Diminished triad parameters
offset1 = 3  # 3 semitones from root to minor third
offset2 = 3  # 3 semitones from minor third to diminished fifth

# Function to add background noise to audio while preserving original volume
def add_noise(audio_data, noise_level):
    """
    Add background noise to audio at specified level without reducing original volume
    noise_level: 0 to 5, where 0 is no noise and 5 is maximum noise
    Returns: audio with added noise, maintaining original signal strength
    """
    # Scale noise level (0-5) to amplitude - SIGNIFICANTLY REDUCED
    # Reducing base amplitude by more than half and using a gentler exponential scale
    base_amplitude = 0.06  # Reduced from 0.15 (60% reduction)
    # Using a much gentler exponential factor (1.8 instead of 3)
    noise_amplitude = base_amplitude * (1.8 ** noise_level) / 32  # Much gentler scaling

    # This combination reduces noise by well over 50% at all levels

    # Convert to float64 for better precision during processing
    audio_float = audio_data.astype(np.float64)

    # Get the maximum value for the audio data type
    max_value = np.iinfo(audio_data.dtype).max

    # Check if audio is stereo (2D array) or mono (1D array)
    is_stereo = len(audio_data.shape) > 1 and audio_data.shape[1] > 1

    # Generate appropriate noise
    if is_stereo:
        # Handle stereo audio (separate noise for each channel)
        noise = np.random.normal(0, max_value * noise_amplitude, audio_data.shape).astype(np.float64)
    else:
        # Handle mono audio
        noise = np.random.normal(0, max_value * noise_amplitude, audio_data.shape[0]).astype(np.float64)

    # Calculate mixing ratio based on noise level
    # This ensures the original signal maintains its volume
    signal_weight = 1.0  # Keep original signal at 100%

    # Mix signal and noise with proper weighting
    mixed_audio = (signal_weight * audio_float) + noise

    # Clip to valid range for the data type
    mixed_audio_clipped = np.clip(mixed_audio, np.iinfo(audio_data.dtype).min, np.iinfo(audio_data.dtype).max)

    # Convert back to original data type
    return mixed_audio_clipped.astype(audio_data.dtype)

def createTriad(inversion, base, offset1, offset2):
    if(inversion==0):
        note1 = base
        note2 = base+offset1
        note3 = note2+offset2

    elif(inversion==1):
        note1 = base+offset1
        note2 = note1+offset2
        note3 = base+12

    elif(inversion==2):
        note1 = base+offset1+offset2
        note2 = base+12
        note3 = note2+offset1

    return note1, note2, note3

print("Generating diminished triad chord MIDI files...")

# Counter for generated files
file_count = 0

# Process all notes in all octaves without limiting
for q, j in zip(nameArray, range(24,109)):
    noteName = q
    base = j

    for h in range(0, 3):  # Loop through all 3 inversions
        inversion = h
        appendInversion = "-"+str(inversion)

        note1, note2, note3 = createTriad(inversion, base, offset1, offset2)
        degrees = [note1, note2, note3]

        track    = 0
        channel  = 0
        time_pos = 0    # In beats (renamed from 'time' to avoid conflict)
        duration = 1    # In beats
        tempo    = 60   # In BPM
        volume   = 100  # 0-127, as per the MIDI standard

        MyMIDI = MIDIFile(1)  # One track
        MyMIDI.addTempo(track, time_pos, tempo)

        # Generate chord (all notes played simultaneously)
        for pitch in degrees:
            MyMIDI.addNote(track, channel, pitch, time_pos, duration, volume)

        midiName = noteName+'-'+chord_type+'-chord'+appendInversion+".mid"
        midi_filename = os.path.join(midi_chord_dir, midiName)

        with open(midi_filename, "wb") as output_file:
            MyMIDI.writeFile(output_file)
            file_count += 1

            # Print progress every 10 files
            if file_count % 10 == 0:
                print(f"Generated {file_count} MIDI files...")

print(f"Completed! Generated {file_count} diminished triad chord MIDI files.")

# Install timidity if not already installed
try:
    subprocess.run(['which', 'timidity'], check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("TiMidity++ is already installed.")
except subprocess.CalledProcessError:
    print("Installing TiMidity++...")
    subprocess.run(['apt-get', 'update'], check=True)
    subprocess.run(['apt-get', 'install', '-y', 'timidity'], check=True)
    print("TiMidity++ installed successfully.")

# Convert MIDI files to WAV with different noise levels
print("\nConverting MIDI files to WAV format with varying noise levels (0-5)...")
wav_count = 0

# Get all MIDI files in the chord directory
midi_files = [f for f in os.listdir(midi_chord_dir) if f.endswith('.mid')]
total_midi_files = len(midi_files)
total_conversions = total_midi_files * 6  # 6 versions of each file (noise levels 0-5)

for idx, midi_file in enumerate(midi_files):
    midi_path = os.path.join(midi_chord_dir, midi_file)
    base_name = Path(midi_file).stem

    print(f"Processing {idx+1}/{total_midi_files}: {midi_file}")

    # First, convert to WAV without noise (temp file)
    temp_wav_path = os.path.join('/tmp', f"{base_name}_temp.wav")

    try:
        # Run timidity with a timeout to prevent hanging
        # Increase the volume of the MIDI files when converting to make them more prominent
        timidity_process = subprocess.run(
            ['timidity', midi_path, '-Ow1', '-s', '16kHz', '-A', '200', '-o', temp_wav_path],
            stdout=subprocess.PIPE, stderr=subprocess.PIPE,
            timeout=10  # Set a 10-second timeout for conversion
        )

        # Check if the temp file was created
        if not os.path.exists(temp_wav_path):
            print(f"Warning: Failed to create WAV file for {midi_file}")
            continue

        # Read the WAV file
        sample_rate, audio_data = wavfile.read(temp_wav_path)

        # Create versions with different noise levels
        for noise_level in range(6):  # 0 to 5
            # Add appropriate level of noise
            if noise_level == 0:
                # No noise for level 0
                noisy_audio = audio_data
            else:
                # Add increasing levels of noise
                noisy_audio = add_noise(audio_data, noise_level)

            # Save to final WAV file with noise level in filename
            wav_file = os.path.join(wav_chord_dir, f"{base_name}_noise{noise_level}.wav")
            wavfile.write(wav_file, sample_rate, noisy_audio)
            wav_count += 1

        # Success message for this file
        print(f"Created 6 variations with different noise levels for {midi_file}")

    except subprocess.TimeoutExpired:
        print(f"Warning: Conversion timeout for {midi_file}")
    except Exception as e:
        print(f"Error processing {midi_file}: {str(e)}")

    # Clean up temp file
    if os.path.exists(temp_wav_path):
        os.remove(temp_wav_path)

    # Add a small delay to prevent overwhelming the system
    time_module.sleep(0.1)  # Using the renamed time module

print(f"\nAll done! Generated {file_count} diminished triad chord MIDI files and {wav_count} WAV files with varying noise levels.")
print(f"MIDI files are in: {midi_chord_dir}")
print(f"WAV files are in: {wav_chord_dir}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Created MIDI directory: /content/drive/MyDrive/MusicGenerator/midi/chords/diminished
# Created WAV directory: /content/drive/MyDrive/MusicGenerator/wav/chords/diminished
# Generating diminished triad chord MIDI files...
# Generated 10 MIDI files...
# Generated 20 MIDI files...
# Generated 30 MIDI files...
# Generated 40 MIDI files...
# Generated 50 MIDI files...
# Generated 60 MIDI files...
# Generated 70 MIDI files...
# Generated 80 MIDI files...
# Generated 90 MIDI files...
# Generated 100 MIDI files...
# Generated 110 MIDI files...
# Generated 120 MIDI files...
# Generated 130 MIDI files...
# Generated 140 MIDI files...
# Generated 150 MIDI files...
# Generated 160 MIDI files...
# Generated 170 MIDI files...
# Generated 180 MIDI files...
# Generated 190 MIDI files...
# Generated 200 MIDI files...
# Generated 210 MIDI files...
# Generated 220 MIDI files...
# Generated 230 MIDI files...
# Generated 240 MIDI files...
# Generated 250 MIDI files...
# Completed! Generated 255 diminished triad chord MIDI files.
# TiMidity++ is already installed.
#
# Converting MIDI files to WAV format with varying noise levels (0-5)...
# Processing 1/255: C-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for C-1-diminished-chord-1.mid
# Processing 2/255: C-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for C-1-diminished-chord-0.mid
# Processing 3/255: C-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for C-1-diminished-chord-2.mid
# Processing 4/255: C#-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for C#-1-diminished-chord-1.mid
# Processing 5/255: C#-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for C#-1-diminished-chord-0.mid
# Processing 6/255: D-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for D-1-diminished-chord-2.mid
# Processing 7/255: D-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for D-1-diminished-chord-0.mid
# Processing 8/255: C#-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for C#-1-diminished-chord-2.mid
# Processing 9/255: D-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for D-1-diminished-chord-1.mid
# Processing 10/255: Eb-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for Eb-1-diminished-chord-1.mid
# Processing 11/255: Eb-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for Eb-1-diminished-chord-2.mid
# Processing 12/255: Eb-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for Eb-1-diminished-chord-0.mid
# Processing 13/255: E-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for E-1-diminished-chord-0.mid
# Processing 14/255: E-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for E-1-diminished-chord-1.mid
# Processing 15/255: E-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for E-1-diminished-chord-2.mid
# Processing 16/255: F#-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for F#-1-diminished-chord-1.mid
# Processing 17/255: F-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for F-1-diminished-chord-0.mid
# Processing 18/255: F#-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for F#-1-diminished-chord-0.mid
# Processing 19/255: F-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for F-1-diminished-chord-1.mid
# Processing 20/255: F-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for F-1-diminished-chord-2.mid
# Processing 21/255: G-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for G-1-diminished-chord-0.mid
# Processing 22/255: G-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for G-1-diminished-chord-1.mid
# Processing 23/255: Ab-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for Ab-1-diminished-chord-0.mid
# Processing 24/255: G-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for G-1-diminished-chord-2.mid
# Processing 25/255: F#-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for F#-1-diminished-chord-2.mid
# Processing 26/255: Ab-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for Ab-1-diminished-chord-1.mid
# Processing 27/255: A-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for A-1-diminished-chord-0.mid
# Processing 28/255: Ab-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for Ab-1-diminished-chord-2.mid
# Processing 29/255: A-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for A-1-diminished-chord-1.mid
# Processing 30/255: A-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for A-1-diminished-chord-2.mid
# Processing 31/255: Bb-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for Bb-1-diminished-chord-2.mid
# Processing 32/255: Bb-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for Bb-1-diminished-chord-0.mid
# Processing 33/255: Bb-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for Bb-1-diminished-chord-1.mid
# Processing 34/255: B-1-diminished-chord-0.mid
# Created 6 variations with different noise levels for B-1-diminished-chord-0.mid
# Processing 35/255: B-1-diminished-chord-1.mid
# Created 6 variations with different noise levels for B-1-diminished-chord-1.mid
# Processing 36/255: C-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for C-2-diminished-chord-0.mid
# Processing 37/255: B-1-diminished-chord-2.mid
# Created 6 variations with different noise levels for B-1-diminished-chord-2.mid
# Processing 38/255: C-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for C-2-diminished-chord-1.mid
# Processing 39/255: C-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for C-2-diminished-chord-2.mid
# Processing 40/255: C#-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for C#-2-diminished-chord-0.mid
# Processing 41/255: D-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for D-2-diminished-chord-0.mid
# Processing 42/255: C#-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for C#-2-diminished-chord-2.mid
# Processing 43/255: C#-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for C#-2-diminished-chord-1.mid
# Processing 44/255: D-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for D-2-diminished-chord-1.mid
# Processing 45/255: D-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for D-2-diminished-chord-2.mid
# Processing 46/255: Eb-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for Eb-2-diminished-chord-0.mid
# Processing 47/255: Eb-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for Eb-2-diminished-chord-1.mid
# Processing 48/255: Eb-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for Eb-2-diminished-chord-2.mid
# Processing 49/255: E-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for E-2-diminished-chord-0.mid
# Processing 50/255: E-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for E-2-diminished-chord-2.mid
# Processing 51/255: E-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for E-2-diminished-chord-1.mid
# Processing 52/255: F-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for F-2-diminished-chord-1.mid
# Processing 53/255: F-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for F-2-diminished-chord-0.mid
# Processing 54/255: F#-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for F#-2-diminished-chord-0.mid
# Processing 55/255: F-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for F-2-diminished-chord-2.mid
# Processing 56/255: F#-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for F#-2-diminished-chord-1.mid
# Processing 57/255: F#-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for F#-2-diminished-chord-2.mid
# Processing 58/255: G-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for G-2-diminished-chord-0.mid
# Processing 59/255: G-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for G-2-diminished-chord-1.mid
# Processing 60/255: G-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for G-2-diminished-chord-2.mid
# Processing 61/255: Ab-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for Ab-2-diminished-chord-0.mid
# Processing 62/255: Ab-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for Ab-2-diminished-chord-1.mid
# Processing 63/255: Ab-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for Ab-2-diminished-chord-2.mid
# Processing 64/255: A-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for A-2-diminished-chord-0.mid
# Processing 65/255: A-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for A-2-diminished-chord-1.mid
# Processing 66/255: A-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for A-2-diminished-chord-2.mid
# Processing 67/255: Bb-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for Bb-2-diminished-chord-0.mid
# Processing 68/255: Bb-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for Bb-2-diminished-chord-1.mid
# Processing 69/255: Bb-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for Bb-2-diminished-chord-2.mid
# Processing 70/255: B-2-diminished-chord-0.mid
# Created 6 variations with different noise levels for B-2-diminished-chord-0.mid
# Processing 71/255: B-2-diminished-chord-1.mid
# Created 6 variations with different noise levels for B-2-diminished-chord-1.mid
# Processing 72/255: B-2-diminished-chord-2.mid
# Created 6 variations with different noise levels for B-2-diminished-chord-2.mid
# Processing 73/255: C-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for C-3-diminished-chord-0.mid
# Processing 74/255: C-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for C-3-diminished-chord-1.mid
# Processing 75/255: C-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for C-3-diminished-chord-2.mid
# Processing 76/255: C#-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for C#-3-diminished-chord-0.mid
# Processing 77/255: C#-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for C#-3-diminished-chord-2.mid
# Processing 78/255: D-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for D-3-diminished-chord-0.mid
# Processing 79/255: C#-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for C#-3-diminished-chord-1.mid
# Processing 80/255: D-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for D-3-diminished-chord-1.mid
# Processing 81/255: Eb-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for Eb-3-diminished-chord-0.mid
# Processing 82/255: D-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for D-3-diminished-chord-2.mid
# Processing 83/255: Eb-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for Eb-3-diminished-chord-2.mid
# Processing 84/255: Eb-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for Eb-3-diminished-chord-1.mid
# Processing 85/255: E-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for E-3-diminished-chord-1.mid
# Processing 86/255: E-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for E-3-diminished-chord-0.mid
# Processing 87/255: E-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for E-3-diminished-chord-2.mid
# Processing 88/255: F-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for F-3-diminished-chord-1.mid
# Processing 89/255: F-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for F-3-diminished-chord-0.mid
# Processing 90/255: F-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for F-3-diminished-chord-2.mid
# Processing 91/255: F#-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for F#-3-diminished-chord-0.mid
# Processing 92/255: F#-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for F#-3-diminished-chord-1.mid
# Processing 93/255: F#-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for F#-3-diminished-chord-2.mid
# Processing 94/255: G-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for G-3-diminished-chord-0.mid
# Processing 95/255: Ab-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for Ab-3-diminished-chord-0.mid
# Processing 96/255: G-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for G-3-diminished-chord-1.mid
# Processing 97/255: G-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for G-3-diminished-chord-2.mid
# Processing 98/255: Ab-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for Ab-3-diminished-chord-1.mid
# Processing 99/255: Ab-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for Ab-3-diminished-chord-2.mid
# Processing 100/255: A-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for A-3-diminished-chord-0.mid
# Processing 101/255: A-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for A-3-diminished-chord-2.mid
# Processing 102/255: A-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for A-3-diminished-chord-1.mid
# Processing 103/255: Bb-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for Bb-3-diminished-chord-0.mid
# Processing 104/255: Bb-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for Bb-3-diminished-chord-1.mid
# Processing 105/255: Bb-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for Bb-3-diminished-chord-2.mid
# Processing 106/255: B-3-diminished-chord-0.mid
# Created 6 variations with different noise levels for B-3-diminished-chord-0.mid
# Processing 107/255: B-3-diminished-chord-2.mid
# Created 6 variations with different noise levels for B-3-diminished-chord-2.mid
# Processing 108/255: B-3-diminished-chord-1.mid
# Created 6 variations with different noise levels for B-3-diminished-chord-1.mid
# Processing 109/255: C-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for C-4-diminished-chord-0.mid
# Processing 110/255: C-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for C-4-diminished-chord-1.mid
# Processing 111/255: C-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for C-4-diminished-chord-2.mid
# Processing 112/255: C#-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for C#-4-diminished-chord-1.mid
# Processing 113/255: C#-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for C#-4-diminished-chord-2.mid
# Processing 114/255: C#-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for C#-4-diminished-chord-0.mid
# Processing 115/255: D-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for D-4-diminished-chord-2.mid
# Processing 116/255: D-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for D-4-diminished-chord-1.mid
# Processing 117/255: D-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for D-4-diminished-chord-0.mid
# Processing 118/255: Eb-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for Eb-4-diminished-chord-1.mid
# Processing 119/255: Eb-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for Eb-4-diminished-chord-0.mid
# Processing 120/255: E-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for E-4-diminished-chord-0.mid
# Processing 121/255: Eb-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for Eb-4-diminished-chord-2.mid
# Processing 122/255: E-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for E-4-diminished-chord-1.mid
# Processing 123/255: E-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for E-4-diminished-chord-2.mid
# Processing 124/255: F-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for F-4-diminished-chord-1.mid
# Processing 125/255: F-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for F-4-diminished-chord-0.mid
# Processing 126/255: F-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for F-4-diminished-chord-2.mid
# Processing 127/255: F#-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for F#-4-diminished-chord-1.mid
# Processing 128/255: F#-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for F#-4-diminished-chord-0.mid
# Processing 129/255: F#-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for F#-4-diminished-chord-2.mid
# Processing 130/255: G-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for G-4-diminished-chord-0.mid
# Processing 131/255: G-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for G-4-diminished-chord-2.mid
# Processing 132/255: G-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for G-4-diminished-chord-1.mid
# Processing 133/255: Ab-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for Ab-4-diminished-chord-0.mid
# Processing 134/255: Ab-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for Ab-4-diminished-chord-1.mid
# Processing 135/255: Ab-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for Ab-4-diminished-chord-2.mid
# Processing 136/255: A-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for A-4-diminished-chord-1.mid
# Processing 137/255: A-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for A-4-diminished-chord-0.mid
# Processing 138/255: Bb-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for Bb-4-diminished-chord-0.mid
# Processing 139/255: A-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for A-4-diminished-chord-2.mid
# Processing 140/255: Bb-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for Bb-4-diminished-chord-2.mid
# Processing 141/255: Bb-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for Bb-4-diminished-chord-1.mid
# Processing 142/255: B-4-diminished-chord-0.mid
# Created 6 variations with different noise levels for B-4-diminished-chord-0.mid
# Processing 143/255: B-4-diminished-chord-1.mid
# Created 6 variations with different noise levels for B-4-diminished-chord-1.mid
# Processing 144/255: B-4-diminished-chord-2.mid
# Created 6 variations with different noise levels for B-4-diminished-chord-2.mid
# Processing 145/255: C-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for C-5-diminished-chord-0.mid
# Processing 146/255: C-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for C-5-diminished-chord-1.mid
# Processing 147/255: C#-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for C#-5-diminished-chord-0.mid
# Processing 148/255: C-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for C-5-diminished-chord-2.mid
# Processing 149/255: C#-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for C#-5-diminished-chord-1.mid
# Processing 150/255: C#-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for C#-5-diminished-chord-2.mid
# Processing 151/255: D-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for D-5-diminished-chord-0.mid
# Processing 152/255: D-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for D-5-diminished-chord-1.mid
# Processing 153/255: Eb-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for Eb-5-diminished-chord-1.mid
# Processing 154/255: D-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for D-5-diminished-chord-2.mid
# Processing 155/255: Eb-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for Eb-5-diminished-chord-0.mid
# Processing 156/255: E-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for E-5-diminished-chord-0.mid
# Processing 157/255: Eb-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for Eb-5-diminished-chord-2.mid
# Processing 158/255: E-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for E-5-diminished-chord-1.mid
# Processing 159/255: E-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for E-5-diminished-chord-2.mid
# Processing 160/255: F-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for F-5-diminished-chord-0.mid
# Processing 161/255: F#-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for F#-5-diminished-chord-1.mid
# Processing 162/255: F-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for F-5-diminished-chord-2.mid
# Processing 163/255: F#-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for F#-5-diminished-chord-0.mid
# Processing 164/255: F-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for F-5-diminished-chord-1.mid
# Processing 165/255: G-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for G-5-diminished-chord-1.mid
# Processing 166/255: G-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for G-5-diminished-chord-2.mid
# Processing 167/255: G-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for G-5-diminished-chord-0.mid
# Processing 168/255: Ab-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for Ab-5-diminished-chord-0.mid
# Processing 169/255: F#-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for F#-5-diminished-chord-2.mid
# Processing 170/255: Ab-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for Ab-5-diminished-chord-2.mid
# Processing 171/255: Ab-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for Ab-5-diminished-chord-1.mid
# Processing 172/255: A-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for A-5-diminished-chord-1.mid
# Processing 173/255: A-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for A-5-diminished-chord-0.mid
# Processing 174/255: A-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for A-5-diminished-chord-2.mid
# Processing 175/255: Bb-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for Bb-5-diminished-chord-1.mid
# Processing 176/255: B-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for B-5-diminished-chord-0.mid
# Processing 177/255: Bb-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for Bb-5-diminished-chord-2.mid
# Processing 178/255: Bb-5-diminished-chord-0.mid
# Created 6 variations with different noise levels for Bb-5-diminished-chord-0.mid
# Processing 179/255: B-5-diminished-chord-1.mid
# Created 6 variations with different noise levels for B-5-diminished-chord-1.mid
# Processing 180/255: C-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for C-6-diminished-chord-0.mid
# Processing 181/255: C-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for C-6-diminished-chord-1.mid
# Processing 182/255: B-5-diminished-chord-2.mid
# Created 6 variations with different noise levels for B-5-diminished-chord-2.mid
# Processing 183/255: C-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for C-6-diminished-chord-2.mid
# Processing 184/255: C#-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for C#-6-diminished-chord-0.mid
# Processing 185/255: C#-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for C#-6-diminished-chord-1.mid
# Processing 186/255: D-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for D-6-diminished-chord-0.mid
# Processing 187/255: C#-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for C#-6-diminished-chord-2.mid
# Processing 188/255: D-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for D-6-diminished-chord-1.mid
# Processing 189/255: D-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for D-6-diminished-chord-2.mid
# Processing 190/255: Eb-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for Eb-6-diminished-chord-2.mid
# Processing 191/255: Eb-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for Eb-6-diminished-chord-1.mid
# Processing 192/255: Eb-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for Eb-6-diminished-chord-0.mid
# Processing 193/255: F-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for F-6-diminished-chord-0.mid
# Processing 194/255: E-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for E-6-diminished-chord-0.mid
# Processing 195/255: E-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for E-6-diminished-chord-1.mid
# Processing 196/255: F-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for F-6-diminished-chord-1.mid
# Processing 197/255: E-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for E-6-diminished-chord-2.mid
# Processing 198/255: F-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for F-6-diminished-chord-2.mid
# Processing 199/255: F#-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for F#-6-diminished-chord-2.mid
# Processing 200/255: F#-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for F#-6-diminished-chord-0.mid
# Processing 201/255: F#-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for F#-6-diminished-chord-1.mid
# Processing 202/255: G-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for G-6-diminished-chord-0.mid
# Processing 203/255: G-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for G-6-diminished-chord-1.mid
# Processing 204/255: G-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for G-6-diminished-chord-2.mid
# Processing 205/255: Ab-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for Ab-6-diminished-chord-1.mid
# Processing 206/255: Ab-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for Ab-6-diminished-chord-0.mid
# Processing 207/255: A-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for A-6-diminished-chord-0.mid
# Processing 208/255: Ab-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for Ab-6-diminished-chord-2.mid
# Processing 209/255: A-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for A-6-diminished-chord-1.mid
# Processing 210/255: A-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for A-6-diminished-chord-2.mid
# Processing 211/255: Bb-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for Bb-6-diminished-chord-0.mid
# Processing 212/255: Bb-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for Bb-6-diminished-chord-2.mid
# Processing 213/255: Bb-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for Bb-6-diminished-chord-1.mid
# Processing 214/255: B-6-diminished-chord-0.mid
# Created 6 variations with different noise levels for B-6-diminished-chord-0.mid
# Processing 215/255: B-6-diminished-chord-1.mid
# Created 6 variations with different noise levels for B-6-diminished-chord-1.mid
# Processing 216/255: B-6-diminished-chord-2.mid
# Created 6 variations with different noise levels for B-6-diminished-chord-2.mid
# Processing 217/255: C-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for C-7-diminished-chord-0.mid
# Processing 218/255: C-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for C-7-diminished-chord-1.mid
# Processing 219/255: C#-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for C#-7-diminished-chord-0.mid
# Processing 220/255: C-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for C-7-diminished-chord-2.mid
# Processing 221/255: C#-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for C#-7-diminished-chord-1.mid
# Processing 222/255: C#-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for C#-7-diminished-chord-2.mid
# Processing 223/255: D-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for D-7-diminished-chord-1.mid
# Processing 224/255: D-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for D-7-diminished-chord-0.mid
# Processing 225/255: Eb-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for Eb-7-diminished-chord-0.mid
# Processing 226/255: D-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for D-7-diminished-chord-2.mid
# Processing 227/255: Eb-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for Eb-7-diminished-chord-1.mid
# Processing 228/255: Eb-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for Eb-7-diminished-chord-2.mid
# Processing 229/255: E-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for E-7-diminished-chord-0.mid
# Processing 230/255: E-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for E-7-diminished-chord-1.mid
# Processing 231/255: F-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for F-7-diminished-chord-0.mid
# Processing 232/255: E-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for E-7-diminished-chord-2.mid
# Processing 233/255: F-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for F-7-diminished-chord-1.mid
# Processing 234/255: F-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for F-7-diminished-chord-2.mid
# Processing 235/255: F#-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for F#-7-diminished-chord-1.mid
# Processing 236/255: F#-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for F#-7-diminished-chord-0.mid
# Processing 237/255: F#-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for F#-7-diminished-chord-2.mid
# Processing 238/255: G-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for G-7-diminished-chord-0.mid
# Processing 239/255: G-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for G-7-diminished-chord-1.mid
# Processing 240/255: G-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for G-7-diminished-chord-2.mid
# Processing 241/255: Ab-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for Ab-7-diminished-chord-0.mid
# Processing 242/255: Ab-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for Ab-7-diminished-chord-1.mid
# Processing 243/255: Ab-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for Ab-7-diminished-chord-2.mid
# Processing 244/255: A-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for A-7-diminished-chord-1.mid
# Processing 245/255: A-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for A-7-diminished-chord-0.mid
# Processing 246/255: Bb-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for Bb-7-diminished-chord-0.mid
# Processing 247/255: A-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for A-7-diminished-chord-2.mid
# Processing 248/255: Bb-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for Bb-7-diminished-chord-1.mid
# Processing 249/255: Bb-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for Bb-7-diminished-chord-2.mid
# Processing 250/255: B-7-diminished-chord-1.mid
# Created 6 variations with different noise levels for B-7-diminished-chord-1.mid
# Processing 251/255: B-7-diminished-chord-0.mid
# Created 6 variations with different noise levels for B-7-diminished-chord-0.mid
# Processing 252/255: C-8-diminished-chord-0.mid
# Created 6 variations with different noise levels for C-8-diminished-chord-0.mid
# Processing 253/255: B-7-diminished-chord-2.mid
# Created 6 variations with different noise levels for B-7-diminished-chord-2.mid
# Processing 254/255: C-8-diminished-chord-1.mid
# Created 6 variations with different noise levels for C-8-diminished-chord-1.mid
# Processing 255/255: C-8-diminished-chord-2.mid
# Created 6 variations with different noise levels for C-8-diminished-chord-2.mid
#
# All done! Generated 255 diminished triad chord MIDI files and 1530 WAV files with varying noise levels.
# MIDI files are in: /content/drive/MyDrive/MusicGenerator/midi/chords/diminished
# WAV files are in: /content/drive/MyDrive/MusicGenerator/wav/chords/diminished

# %%
#augmented

from midiutil import MIDIFile
import os
import subprocess
import numpy as np
from scipy.io import wavfile
from pathlib import Path
from google.colab import drive
import time as time_module  # Renamed to avoid conflict

# Mount Google Drive
drive.mount('/content/drive')

# Define the paths
base_dir = '/content/drive/MyDrive/MusicGenerator'
midi_dir = os.path.join(base_dir, "midi")
wav_dir = os.path.join(base_dir, "wav")

# Create directories if they don't exist
chord_type = "augmented"
midi_chord_dir = os.path.join(midi_dir, "chords", chord_type)
wav_chord_dir = os.path.join(wav_dir, "chords", chord_type)

# Create necessary directories
Path(midi_chord_dir).mkdir(parents=True, exist_ok=True)
Path(wav_chord_dir).mkdir(parents=True, exist_ok=True)

print(f"Created MIDI directory: {midi_chord_dir}")
print(f"Created WAV directory: {wav_chord_dir}")

# Install required packages if needed
try:
    import scipy
except ImportError:
    print("Installing scipy...")
    subprocess.run(['pip', 'install', 'scipy'], check=True)
    from scipy.io import wavfile

noteArray = ["C", "C#", "D", "Eb", "E", "F", "F#", "G", "Ab", "A", "Bb", "B"]
octaveArray = [1, 2, 3, 4, 5, 6, 7, 8]  # Using the full octave range 1-8

# Generate note names with octaves (C-1, C-2, etc.)
nameArray = []
for octave in octaveArray:
    for note in noteArray:
        nameArray.append(f"{note}-{octave}")

# Augmented triad parameters
offset1 = 4  # 4 semitones from root to major third
offset2 = 4  # 4 semitones from major third to augmented fifth

# Function to add background noise to audio while preserving original volume
def add_noise(audio_data, noise_level):
    """
    Add background noise to audio at specified level without reducing original volume
    noise_level: 0 to 5, where 0 is no noise and 5 is maximum noise
    Returns: audio with added noise, maintaining original signal strength
    """
    # Scale noise level (0-5) to amplitude - SIGNIFICANTLY REDUCED
    # Reducing base amplitude by more than half and using a gentler exponential scale
    base_amplitude = 0.06  # Reduced from 0.15 (60% reduction)
    # Using a much gentler exponential factor (1.8 instead of 3)
    noise_amplitude = base_amplitude * (1.8 ** noise_level) / 32  # Much gentler scaling

    # This combination reduces noise by well over 50% at all levels

    # Convert to float64 for better precision during processing
    audio_float = audio_data.astype(np.float64)

    # Get the maximum value for the audio data type
    max_value = np.iinfo(audio_data.dtype).max

    # Check if audio is stereo (2D array) or mono (1D array)
    is_stereo = len(audio_data.shape) > 1 and audio_data.shape[1] > 1

    # Generate appropriate noise
    if is_stereo:
        # Handle stereo audio (separate noise for each channel)
        noise = np.random.normal(0, max_value * noise_amplitude, audio_data.shape).astype(np.float64)
    else:
        # Handle mono audio
        noise = np.random.normal(0, max_value * noise_amplitude, audio_data.shape[0]).astype(np.float64)

    # Calculate mixing ratio based on noise level
    # This ensures the original signal maintains its volume
    signal_weight = 1.0  # Keep original signal at 100%

    # Mix signal and noise with proper weighting
    mixed_audio = (signal_weight * audio_float) + noise

    # Clip to valid range for the data type
    mixed_audio_clipped = np.clip(mixed_audio, np.iinfo(audio_data.dtype).min, np.iinfo(audio_data.dtype).max)

    # Convert back to original data type
    return mixed_audio_clipped.astype(audio_data.dtype)

def createTriad(inversion, base, offset1, offset2):
    if(inversion==0):
        note1 = base
        note2 = base+offset1
        note3 = note2+offset2

    elif(inversion==1):
        note1 = base+offset1
        note2 = note1+offset2
        note3 = base+12

    elif(inversion==2):
        note1 = base+offset1+offset2
        note2 = base+12
        note3 = note2+offset1

    return note1, note2, note3

print("Generating augmented triad chord MIDI files...")

# Counter for generated files
file_count = 0

# Process all notes in all octaves without limiting
for q, j in zip(nameArray, range(24,109)):
    noteName = q
    base = j

    for h in range(0, 3):  # Loop through all 3 inversions
        inversion = h
        appendInversion = "-"+str(inversion)

        note1, note2, note3 = createTriad(inversion, base, offset1, offset2)
        degrees = [note1, note2, note3]

        track    = 0
        channel  = 0
        time_pos = 0    # In beats (renamed from 'time' to avoid conflict)
        duration = 1    # In beats
        tempo    = 60   # In BPM
        volume   = 100  # 0-127, as per the MIDI standard

        MyMIDI = MIDIFile(1)  # One track
        MyMIDI.addTempo(track, time_pos, tempo)

        # Generate chord (all notes played simultaneously)
        for pitch in degrees:
            MyMIDI.addNote(track, channel, pitch, time_pos, duration, volume)

        midiName = noteName+'-'+chord_type+'-chord'+appendInversion+".mid"
        midi_filename = os.path.join(midi_chord_dir, midiName)

        with open(midi_filename, "wb") as output_file:
            MyMIDI.writeFile(output_file)
            file_count += 1

            # Print progress every 10 files
            if file_count % 10 == 0:
                print(f"Generated {file_count} MIDI files...")

print(f"Completed! Generated {file_count} augmented triad chord MIDI files.")

# Install timidity if not already installed
try:
    subprocess.run(['which', 'timidity'], check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("TiMidity++ is already installed.")
except subprocess.CalledProcessError:
    print("Installing TiMidity++...")
    subprocess.run(['apt-get', 'update'], check=True)
    subprocess.run(['apt-get', 'install', '-y', 'timidity'], check=True)
    print("TiMidity++ installed successfully.")

# Convert MIDI files to WAV with different noise levels
print("\nConverting MIDI files to WAV format with varying noise levels (0-5)...")
wav_count = 0

# Get all MIDI files in the chord directory
midi_files = [f for f in os.listdir(midi_chord_dir) if f.endswith('.mid')]
total_midi_files = len(midi_files)
total_conversions = total_midi_files * 6  # 6 versions of each file (noise levels 0-5)

for idx, midi_file in enumerate(midi_files):
    midi_path = os.path.join(midi_chord_dir, midi_file)
    base_name = Path(midi_file).stem

    print(f"Processing {idx+1}/{total_midi_files}: {midi_file}")

    # First, convert to WAV without noise (temp file)
    temp_wav_path = os.path.join('/tmp', f"{base_name}_temp.wav")

    try:
        # Run timidity with a timeout to prevent hanging
        # Increase the volume of the MIDI files when converting to make them more prominent
        timidity_process = subprocess.run(
            ['timidity', midi_path, '-Ow1', '-s', '16kHz', '-A', '200', '-o', temp_wav_path],
            stdout=subprocess.PIPE, stderr=subprocess.PIPE,
            timeout=10  # Set a 10-second timeout for conversion
        )

        # Check if the temp file was created
        if not os.path.exists(temp_wav_path):
            print(f"Warning: Failed to create WAV file for {midi_file}")
            continue

        # Read the WAV file
        sample_rate, audio_data = wavfile.read(temp_wav_path)

        # Create versions with different noise levels
        for noise_level in range(6):  # 0 to 5
            # Add appropriate level of noise
            if noise_level == 0:
                # No noise for level 0
                noisy_audio = audio_data
            else:
                # Add increasing levels of noise
                noisy_audio = add_noise(audio_data, noise_level)

            # Save to final WAV file with noise level in filename
            wav_file = os.path.join(wav_chord_dir, f"{base_name}_noise{noise_level}.wav")
            wavfile.write(wav_file, sample_rate, noisy_audio)
            wav_count += 1

        # Success message for this file
        print(f"Created 6 variations with different noise levels for {midi_file}")

    except subprocess.TimeoutExpired:
        print(f"Warning: Conversion timeout for {midi_file}")
    except Exception as e:
        print(f"Error processing {midi_file}: {str(e)}")

    # Clean up temp file
    if os.path.exists(temp_wav_path):
        os.remove(temp_wav_path)

    # Add a small delay to prevent overwhelming the system
    time_module.sleep(0.1)  # Using the renamed time module

print(f"\nAll done! Generated {file_count} augmented triad chord MIDI files and {wav_count} WAV files with varying noise levels.")
print(f"MIDI files are in: {midi_chord_dir}")
print(f"WAV files are in: {wav_chord_dir}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Created MIDI directory: /content/drive/MyDrive/MusicGenerator/midi/chords/augmented
# Created WAV directory: /content/drive/MyDrive/MusicGenerator/wav/chords/augmented
# Generating augmented triad chord MIDI files...
# Generated 10 MIDI files...
# Generated 20 MIDI files...
# Generated 30 MIDI files...
# Generated 40 MIDI files...
# Generated 50 MIDI files...
# Generated 60 MIDI files...
# Generated 70 MIDI files...
# Generated 80 MIDI files...
# Generated 90 MIDI files...
# Generated 100 MIDI files...
# Generated 110 MIDI files...
# Generated 120 MIDI files...
# Generated 130 MIDI files...
# Generated 140 MIDI files...
# Generated 150 MIDI files...
# Generated 160 MIDI files...
# Generated 170 MIDI files...
# Generated 180 MIDI files...
# Generated 190 MIDI files...
# Generated 200 MIDI files...
# Generated 210 MIDI files...
# Generated 220 MIDI files...
# Generated 230 MIDI files...
# Generated 240 MIDI files...
# Generated 250 MIDI files...
# Completed! Generated 255 augmented triad chord MIDI files.
# TiMidity++ is already installed.
#
# Converting MIDI files to WAV format with varying noise levels (0-5)...
# Processing 1/255: C#-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for C#-1-augmented-chord-1.mid
# Processing 2/255: C-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for C-1-augmented-chord-0.mid
# Processing 3/255: D-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for D-1-augmented-chord-2.mid
# Processing 4/255: C-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for C-1-augmented-chord-2.mid
# Processing 5/255: Eb-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for Eb-1-augmented-chord-0.mid
# Processing 6/255: D-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for D-1-augmented-chord-1.mid
# Processing 7/255: C-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for C-1-augmented-chord-1.mid
# Processing 8/255: C#-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for C#-1-augmented-chord-2.mid
# Processing 9/255: C#-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for C#-1-augmented-chord-0.mid
# Processing 10/255: D-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for D-1-augmented-chord-0.mid
# Processing 11/255: Eb-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for Eb-1-augmented-chord-1.mid
# Processing 12/255: Eb-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for Eb-1-augmented-chord-2.mid
# Processing 13/255: E-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for E-1-augmented-chord-0.mid
# Processing 14/255: E-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for E-1-augmented-chord-2.mid
# Processing 15/255: E-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for E-1-augmented-chord-1.mid
# Processing 16/255: F-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for F-1-augmented-chord-2.mid
# Processing 17/255: F#-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for F#-1-augmented-chord-0.mid
# Processing 18/255: F-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for F-1-augmented-chord-0.mid
# Processing 19/255: F-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for F-1-augmented-chord-1.mid
# Processing 20/255: F#-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for F#-1-augmented-chord-1.mid
# Processing 21/255: F#-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for F#-1-augmented-chord-2.mid
# Processing 22/255: G-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for G-1-augmented-chord-0.mid
# Processing 23/255: G-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for G-1-augmented-chord-1.mid
# Processing 24/255: G-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for G-1-augmented-chord-2.mid
# Processing 25/255: Ab-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for Ab-1-augmented-chord-0.mid
# Processing 26/255: A-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for A-1-augmented-chord-0.mid
# Processing 27/255: A-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for A-1-augmented-chord-2.mid
# Processing 28/255: Ab-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for Ab-1-augmented-chord-1.mid
# Processing 29/255: Ab-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for Ab-1-augmented-chord-2.mid
# Processing 30/255: A-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for A-1-augmented-chord-1.mid
# Processing 31/255: Bb-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for Bb-1-augmented-chord-0.mid
# Processing 32/255: Bb-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for Bb-1-augmented-chord-1.mid
# Processing 33/255: Bb-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for Bb-1-augmented-chord-2.mid
# Processing 34/255: B-1-augmented-chord-0.mid
# Created 6 variations with different noise levels for B-1-augmented-chord-0.mid
# Processing 35/255: B-1-augmented-chord-1.mid
# Created 6 variations with different noise levels for B-1-augmented-chord-1.mid
# Processing 36/255: C-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for C-2-augmented-chord-0.mid
# Processing 37/255: B-1-augmented-chord-2.mid
# Created 6 variations with different noise levels for B-1-augmented-chord-2.mid
# Processing 38/255: C-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for C-2-augmented-chord-2.mid
# Processing 39/255: C-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for C-2-augmented-chord-1.mid
# Processing 40/255: C#-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for C#-2-augmented-chord-0.mid
# Processing 41/255: C#-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for C#-2-augmented-chord-2.mid
# Processing 42/255: C#-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for C#-2-augmented-chord-1.mid
# Processing 43/255: D-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for D-2-augmented-chord-0.mid
# Processing 44/255: D-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for D-2-augmented-chord-2.mid
# Processing 45/255: D-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for D-2-augmented-chord-1.mid
# Processing 46/255: Eb-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for Eb-2-augmented-chord-0.mid
# Processing 47/255: Eb-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for Eb-2-augmented-chord-1.mid
# Processing 48/255: Eb-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for Eb-2-augmented-chord-2.mid
# Processing 49/255: E-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for E-2-augmented-chord-0.mid
# Processing 50/255: E-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for E-2-augmented-chord-1.mid
# Processing 51/255: E-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for E-2-augmented-chord-2.mid
# Processing 52/255: F-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for F-2-augmented-chord-0.mid
# Processing 53/255: F-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for F-2-augmented-chord-1.mid
# Processing 54/255: F-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for F-2-augmented-chord-2.mid
# Processing 55/255: F#-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for F#-2-augmented-chord-0.mid
# Processing 56/255: F#-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for F#-2-augmented-chord-1.mid
# Processing 57/255: F#-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for F#-2-augmented-chord-2.mid
# Processing 58/255: G-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for G-2-augmented-chord-0.mid
# Processing 59/255: G-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for G-2-augmented-chord-2.mid
# Processing 60/255: G-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for G-2-augmented-chord-1.mid
# Processing 61/255: Ab-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for Ab-2-augmented-chord-0.mid
# Processing 62/255: Ab-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for Ab-2-augmented-chord-2.mid
# Processing 63/255: Ab-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for Ab-2-augmented-chord-1.mid
# Processing 64/255: A-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for A-2-augmented-chord-0.mid
# Processing 65/255: A-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for A-2-augmented-chord-1.mid
# Processing 66/255: A-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for A-2-augmented-chord-2.mid
# Processing 67/255: Bb-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for Bb-2-augmented-chord-0.mid
# Processing 68/255: Bb-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for Bb-2-augmented-chord-1.mid
# Processing 69/255: Bb-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for Bb-2-augmented-chord-2.mid
# Processing 70/255: B-2-augmented-chord-0.mid
# Created 6 variations with different noise levels for B-2-augmented-chord-0.mid
# Processing 71/255: B-2-augmented-chord-1.mid
# Created 6 variations with different noise levels for B-2-augmented-chord-1.mid
# Processing 72/255: B-2-augmented-chord-2.mid
# Created 6 variations with different noise levels for B-2-augmented-chord-2.mid
# Processing 73/255: C-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for C-3-augmented-chord-0.mid
# Processing 74/255: C-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for C-3-augmented-chord-1.mid
# Processing 75/255: C-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for C-3-augmented-chord-2.mid
# Processing 76/255: C#-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for C#-3-augmented-chord-0.mid
# Processing 77/255: C#-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for C#-3-augmented-chord-1.mid
# Processing 78/255: C#-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for C#-3-augmented-chord-2.mid
# Processing 79/255: D-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for D-3-augmented-chord-0.mid
# Processing 80/255: D-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for D-3-augmented-chord-2.mid
# Processing 81/255: D-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for D-3-augmented-chord-1.mid
# Processing 82/255: Eb-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for Eb-3-augmented-chord-0.mid
# Processing 83/255: Eb-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for Eb-3-augmented-chord-1.mid
# Processing 84/255: E-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for E-3-augmented-chord-0.mid
# Processing 85/255: Eb-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for Eb-3-augmented-chord-2.mid
# Processing 86/255: F-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for F-3-augmented-chord-0.mid
# Processing 87/255: E-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for E-3-augmented-chord-2.mid
# Processing 88/255: E-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for E-3-augmented-chord-1.mid
# Processing 89/255: F-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for F-3-augmented-chord-2.mid
# Processing 90/255: F-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for F-3-augmented-chord-1.mid
# Processing 91/255: F#-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for F#-3-augmented-chord-0.mid
# Processing 92/255: F#-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for F#-3-augmented-chord-1.mid
# Processing 93/255: G-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for G-3-augmented-chord-0.mid
# Processing 94/255: F#-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for F#-3-augmented-chord-2.mid
# Processing 95/255: G-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for G-3-augmented-chord-2.mid
# Processing 96/255: G-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for G-3-augmented-chord-1.mid
# Processing 97/255: Ab-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for Ab-3-augmented-chord-1.mid
# Processing 98/255: Ab-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for Ab-3-augmented-chord-0.mid
# Processing 99/255: Ab-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for Ab-3-augmented-chord-2.mid
# Processing 100/255: A-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for A-3-augmented-chord-0.mid
# Processing 101/255: A-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for A-3-augmented-chord-1.mid
# Processing 102/255: A-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for A-3-augmented-chord-2.mid
# Processing 103/255: Bb-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for Bb-3-augmented-chord-0.mid
# Processing 104/255: Bb-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for Bb-3-augmented-chord-1.mid
# Processing 105/255: Bb-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for Bb-3-augmented-chord-2.mid
# Processing 106/255: B-3-augmented-chord-0.mid
# Created 6 variations with different noise levels for B-3-augmented-chord-0.mid
# Processing 107/255: B-3-augmented-chord-1.mid
# Created 6 variations with different noise levels for B-3-augmented-chord-1.mid
# Processing 108/255: B-3-augmented-chord-2.mid
# Created 6 variations with different noise levels for B-3-augmented-chord-2.mid
# Processing 109/255: C-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for C-4-augmented-chord-0.mid
# Processing 110/255: C-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for C-4-augmented-chord-2.mid
# Processing 111/255: C-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for C-4-augmented-chord-1.mid
# Processing 112/255: C#-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for C#-4-augmented-chord-0.mid
# Processing 113/255: C#-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for C#-4-augmented-chord-1.mid
# Processing 114/255: C#-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for C#-4-augmented-chord-2.mid
# Processing 115/255: D-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for D-4-augmented-chord-0.mid
# Processing 116/255: D-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for D-4-augmented-chord-1.mid
# Processing 117/255: Eb-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for Eb-4-augmented-chord-0.mid
# Processing 118/255: D-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for D-4-augmented-chord-2.mid
# Processing 119/255: Eb-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for Eb-4-augmented-chord-1.mid
# Processing 120/255: Eb-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for Eb-4-augmented-chord-2.mid
# Processing 121/255: E-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for E-4-augmented-chord-1.mid
# Processing 122/255: E-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for E-4-augmented-chord-0.mid
# Processing 123/255: E-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for E-4-augmented-chord-2.mid
# Processing 124/255: F-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for F-4-augmented-chord-0.mid
# Processing 125/255: F-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for F-4-augmented-chord-1.mid
# Processing 126/255: F-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for F-4-augmented-chord-2.mid
# Processing 127/255: F#-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for F#-4-augmented-chord-0.mid
# Processing 128/255: F#-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for F#-4-augmented-chord-1.mid
# Processing 129/255: F#-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for F#-4-augmented-chord-2.mid
# Processing 130/255: G-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for G-4-augmented-chord-0.mid
# Processing 131/255: G-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for G-4-augmented-chord-1.mid
# Processing 132/255: G-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for G-4-augmented-chord-2.mid
# Processing 133/255: Ab-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for Ab-4-augmented-chord-0.mid
# Processing 134/255: Ab-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for Ab-4-augmented-chord-2.mid
# Processing 135/255: Ab-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for Ab-4-augmented-chord-1.mid
# Processing 136/255: A-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for A-4-augmented-chord-0.mid
# Processing 137/255: A-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for A-4-augmented-chord-2.mid
# Processing 138/255: A-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for A-4-augmented-chord-1.mid
# Processing 139/255: Bb-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for Bb-4-augmented-chord-0.mid
# Processing 140/255: Bb-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for Bb-4-augmented-chord-1.mid
# Processing 141/255: Bb-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for Bb-4-augmented-chord-2.mid
# Processing 142/255: B-4-augmented-chord-0.mid
# Created 6 variations with different noise levels for B-4-augmented-chord-0.mid
# Processing 143/255: B-4-augmented-chord-2.mid
# Created 6 variations with different noise levels for B-4-augmented-chord-2.mid
# Processing 144/255: B-4-augmented-chord-1.mid
# Created 6 variations with different noise levels for B-4-augmented-chord-1.mid
# Processing 145/255: C-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for C-5-augmented-chord-0.mid
# Processing 146/255: C-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for C-5-augmented-chord-1.mid
# Processing 147/255: C-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for C-5-augmented-chord-2.mid
# Processing 148/255: C#-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for C#-5-augmented-chord-0.mid
# Processing 149/255: C#-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for C#-5-augmented-chord-1.mid
# Processing 150/255: C#-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for C#-5-augmented-chord-2.mid
# Processing 151/255: D-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for D-5-augmented-chord-0.mid
# Processing 152/255: D-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for D-5-augmented-chord-1.mid
# Processing 153/255: D-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for D-5-augmented-chord-2.mid
# Processing 154/255: Eb-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for Eb-5-augmented-chord-0.mid
# Processing 155/255: Eb-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for Eb-5-augmented-chord-1.mid
# Processing 156/255: Eb-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for Eb-5-augmented-chord-2.mid
# Processing 157/255: E-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for E-5-augmented-chord-1.mid
# Processing 158/255: E-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for E-5-augmented-chord-0.mid
# Processing 159/255: E-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for E-5-augmented-chord-2.mid
# Processing 160/255: F-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for F-5-augmented-chord-0.mid
# Processing 161/255: F-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for F-5-augmented-chord-2.mid
# Processing 162/255: F-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for F-5-augmented-chord-1.mid
# Processing 163/255: F#-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for F#-5-augmented-chord-0.mid
# Processing 164/255: F#-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for F#-5-augmented-chord-1.mid
# Processing 165/255: F#-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for F#-5-augmented-chord-2.mid
# Processing 166/255: G-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for G-5-augmented-chord-0.mid
# Processing 167/255: G-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for G-5-augmented-chord-1.mid
# Processing 168/255: Ab-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for Ab-5-augmented-chord-0.mid
# Processing 169/255: G-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for G-5-augmented-chord-2.mid
# Processing 170/255: Ab-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for Ab-5-augmented-chord-1.mid
# Processing 171/255: Ab-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for Ab-5-augmented-chord-2.mid
# Processing 172/255: A-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for A-5-augmented-chord-0.mid
# Processing 173/255: A-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for A-5-augmented-chord-1.mid
# Processing 174/255: A-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for A-5-augmented-chord-2.mid
# Processing 175/255: Bb-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for Bb-5-augmented-chord-0.mid
# Processing 176/255: Bb-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for Bb-5-augmented-chord-2.mid
# Processing 177/255: Bb-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for Bb-5-augmented-chord-1.mid
# Processing 178/255: B-5-augmented-chord-0.mid
# Created 6 variations with different noise levels for B-5-augmented-chord-0.mid
# Processing 179/255: B-5-augmented-chord-2.mid
# Created 6 variations with different noise levels for B-5-augmented-chord-2.mid
# Processing 180/255: B-5-augmented-chord-1.mid
# Created 6 variations with different noise levels for B-5-augmented-chord-1.mid
# Processing 181/255: C-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for C-6-augmented-chord-0.mid
# Processing 182/255: C-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for C-6-augmented-chord-1.mid
# Processing 183/255: C-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for C-6-augmented-chord-2.mid
# Processing 184/255: C#-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for C#-6-augmented-chord-0.mid
# Processing 185/255: C#-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for C#-6-augmented-chord-1.mid
# Processing 186/255: C#-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for C#-6-augmented-chord-2.mid
# Processing 187/255: D-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for D-6-augmented-chord-0.mid
# Processing 188/255: D-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for D-6-augmented-chord-2.mid
# Processing 189/255: Eb-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for Eb-6-augmented-chord-0.mid
# Processing 190/255: D-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for D-6-augmented-chord-1.mid
# Processing 191/255: Eb-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for Eb-6-augmented-chord-2.mid
# Processing 192/255: Eb-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for Eb-6-augmented-chord-1.mid
# Processing 193/255: E-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for E-6-augmented-chord-0.mid
# Processing 194/255: E-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for E-6-augmented-chord-1.mid
# Processing 195/255: E-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for E-6-augmented-chord-2.mid
# Processing 196/255: F-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for F-6-augmented-chord-0.mid
# Processing 197/255: F-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for F-6-augmented-chord-2.mid
# Processing 198/255: F-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for F-6-augmented-chord-1.mid
# Processing 199/255: F#-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for F#-6-augmented-chord-0.mid
# Processing 200/255: F#-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for F#-6-augmented-chord-1.mid
# Processing 201/255: F#-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for F#-6-augmented-chord-2.mid
# Processing 202/255: G-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for G-6-augmented-chord-1.mid
# Processing 203/255: G-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for G-6-augmented-chord-0.mid
# Processing 204/255: G-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for G-6-augmented-chord-2.mid
# Processing 205/255: Ab-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for Ab-6-augmented-chord-0.mid
# Processing 206/255: Ab-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for Ab-6-augmented-chord-1.mid
# Processing 207/255: Ab-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for Ab-6-augmented-chord-2.mid
# Processing 208/255: A-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for A-6-augmented-chord-0.mid
# Processing 209/255: A-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for A-6-augmented-chord-1.mid
# Processing 210/255: Bb-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for Bb-6-augmented-chord-0.mid
# Processing 211/255: A-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for A-6-augmented-chord-2.mid
# Processing 212/255: Bb-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for Bb-6-augmented-chord-1.mid
# Processing 213/255: Bb-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for Bb-6-augmented-chord-2.mid
# Processing 214/255: B-6-augmented-chord-1.mid
# Created 6 variations with different noise levels for B-6-augmented-chord-1.mid
# Processing 215/255: B-6-augmented-chord-0.mid
# Created 6 variations with different noise levels for B-6-augmented-chord-0.mid
# Processing 216/255: B-6-augmented-chord-2.mid
# Created 6 variations with different noise levels for B-6-augmented-chord-2.mid
# Processing 217/255: C-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for C-7-augmented-chord-0.mid
# Processing 218/255: C-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for C-7-augmented-chord-1.mid
# Processing 219/255: C#-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for C#-7-augmented-chord-0.mid
# Processing 220/255: C-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for C-7-augmented-chord-2.mid
# Processing 221/255: C#-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for C#-7-augmented-chord-1.mid
# Processing 222/255: C#-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for C#-7-augmented-chord-2.mid
# Processing 223/255: D-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for D-7-augmented-chord-1.mid
# Processing 224/255: D-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for D-7-augmented-chord-0.mid
# Processing 225/255: D-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for D-7-augmented-chord-2.mid
# Processing 226/255: Eb-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for Eb-7-augmented-chord-0.mid
# Processing 227/255: Eb-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for Eb-7-augmented-chord-1.mid
# Processing 228/255: Eb-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for Eb-7-augmented-chord-2.mid
# Processing 229/255: E-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for E-7-augmented-chord-0.mid
# Processing 230/255: E-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for E-7-augmented-chord-2.mid
# Processing 231/255: E-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for E-7-augmented-chord-1.mid
# Processing 232/255: F-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for F-7-augmented-chord-0.mid
# Processing 233/255: F-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for F-7-augmented-chord-1.mid
# Processing 234/255: F-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for F-7-augmented-chord-2.mid
# Processing 235/255: F#-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for F#-7-augmented-chord-0.mid
# Processing 236/255: F#-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for F#-7-augmented-chord-1.mid
# Processing 237/255: F#-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for F#-7-augmented-chord-2.mid
# Processing 238/255: G-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for G-7-augmented-chord-0.mid
# Processing 239/255: G-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for G-7-augmented-chord-1.mid
# Processing 240/255: G-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for G-7-augmented-chord-2.mid
# Processing 241/255: Ab-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for Ab-7-augmented-chord-0.mid
# Processing 242/255: Ab-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for Ab-7-augmented-chord-1.mid
# Processing 243/255: Ab-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for Ab-7-augmented-chord-2.mid
# Processing 244/255: A-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for A-7-augmented-chord-0.mid
# Processing 245/255: A-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for A-7-augmented-chord-1.mid
# Processing 246/255: A-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for A-7-augmented-chord-2.mid
# Processing 247/255: Bb-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for Bb-7-augmented-chord-0.mid
# Processing 248/255: Bb-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for Bb-7-augmented-chord-1.mid
# Processing 249/255: Bb-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for Bb-7-augmented-chord-2.mid
# Processing 250/255: B-7-augmented-chord-1.mid
# Created 6 variations with different noise levels for B-7-augmented-chord-1.mid
# Processing 251/255: B-7-augmented-chord-0.mid
# Created 6 variations with different noise levels for B-7-augmented-chord-0.mid
# Processing 252/255: B-7-augmented-chord-2.mid
# Created 6 variations with different noise levels for B-7-augmented-chord-2.mid
# Processing 253/255: C-8-augmented-chord-1.mid
# Created 6 variations with different noise levels for C-8-augmented-chord-1.mid
# Processing 254/255: C-8-augmented-chord-0.mid
# Created 6 variations with different noise levels for C-8-augmented-chord-0.mid
# Processing 255/255: C-8-augmented-chord-2.mid
# Created 6 variations with different noise levels for C-8-augmented-chord-2.mid
#
# All done! Generated 255 augmented triad chord MIDI files and 1530 WAV files with varying noise levels.
# MIDI files are in: /content/drive/MyDrive/MusicGenerator/midi/chords/augmented
# WAV files are in: /content/drive/MyDrive/MusicGenerator/wav/chords/augmented
